# %%
#Import the libraries I'll use.
import pandas as pd
import requests
from datetime import datetime
from bs4 import BeautifulSoup as bs
import bs4
import json
import re

# %% [markdown]
# # Working Area:

# %%
#Starting by looking at a specific game page and looking what class is the box info.
r = requests.get("https://en.wikipedia.org/wiki/Grand_Theft_Auto_V")
soups = bs(r.content,"lxml")

info_box = soups.find(class_="infobox hproduct")
info_rows = info_box.select("tr")
for row in info_rows:
    print(row.prettify())
# Out:
# <tr>
#  <th class="infobox-above fn" colspan="2" style="font-size:125%;font-style:italic;">
#   Grand Theft Auto V
#  </th>
# </tr>
#
# <tr>
#  <td class="infobox-image" colspan="2">
#   <a class="image" href="/wiki/File:Grand_Theft_Auto_V.png">
#    <img alt="Grand Theft Auto V.png" data-file-height="350" data-file-width="285" decoding="async" height="270" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a5/Grand_Theft_Auto_V.png/220px-Grand_Theft_Auto_V.png" srcset="//upload.wikimedia.org/wikipedia/en/a/a5/Grand_Theft_Auto_V.png 1.5x" width="220"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_developer" title="Video game developer">
#    Developer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <a href="/wiki/Rockstar_North" title="Rockstar North">
#    Rockstar North
#   </a>
#   <sup class="reference" id="cite_ref-2">
#    <a href="#cite_note-2">
#     [a]
#    </a>
#   </sup>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_publisher" title="Video game publisher">
#    Publisher(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <a href="/wiki/Rockstar_Games" title="Rockstar Games">
#    Rockstar Games
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_producer" title="Video game producer">
#    Producer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <div class="plainlist">
#    <ul>
#     <li>
#      <a href="/wiki/Leslie_Benzies" title="Leslie Benzies">
#       Leslie Benzies
#      </a>
#     </li>
#     <li>
#      Imran Sarwar
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a class="mw-redirect" href="/wiki/Video_game_designer" title="Video game designer">
#    Designer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <div class="plainlist">
#    <ul>
#     <li>
#      Leslie Benzies
#     </li>
#     <li>
#      Imran Sarwar
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_programmer" title="Video game programmer">
#    Programmer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   Adam Fowler
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_artist" title="Video game artist">
#    Artist(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   Aaron Garbut
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a class="mw-redirect" href="/wiki/Video_game_writer" title="Video game writer">
#    Writer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <div class="plainlist">
#    <ul>
#     <li>
#      <a href="/wiki/Dan_Houser" title="Dan Houser">
#       Dan Houser
#      </a>
#     </li>
#     <li>
#      Rupert Humphries
#     </li>
#     <li>
#      Michael Unsworth
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a class="mw-redirect" href="/wiki/Video_game_composer" title="Video game composer">
#    Composer(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <div class="plainlist">
#    <ul>
#     <li>
#      <a href="/wiki/Tangerine_Dream" title="Tangerine Dream">
#       Tangerine Dream
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/Woody_Jackson" title="Woody Jackson">
#       Woody Jackson
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/The_Alchemist_(musician)" title="The Alchemist (musician)">
#       The Alchemist
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/Oh_No_(musician)" title="Oh No (musician)">
#       Oh No
#      </a>
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   Series
#  </th>
#  <td class="infobox-data">
#   <i>
#    <a href="/wiki/Grand_Theft_Auto" title="Grand Theft Auto">
#     Grand Theft Auto
#    </a>
#   </i>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Game_engine" title="Game engine">
#    Engine
#   </a>
#  </th>
#  <td class="infobox-data">
#   <a href="/wiki/Rockstar_Advanced_Game_Engine" title="Rockstar Advanced Game Engine">
#    RAGE
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Computing_platform" title="Computing platform">
#    Platform(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <div class="plainlist">
#    <ul>
#     <li>
#      <a href="/wiki/PlayStation_3" title="PlayStation 3">
#       PlayStation 3
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/Xbox_360" title="Xbox 360">
#       Xbox 360
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/PlayStation_4" title="PlayStation 4">
#       PlayStation 4
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/Xbox_One" title="Xbox One">
#       Xbox One
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/Microsoft_Windows" title="Microsoft Windows">
#       Microsoft Windows
#      </a>
#     </li>
#     <li>
#      <a href="/wiki/PlayStation_5" title="PlayStation 5">
#       PlayStation 5
#      </a>
#     </li>
#     <li>
#      <a class="mw-redirect" href="/wiki/Xbox_Series_X/S" title="Xbox Series X/S">
#       Xbox Series X/S
#      </a>
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   Release
#  </th>
#  <td class="infobox-data">
#   <div class="mw-collapsible mw-collapsed" style="text-align: center; font-size: 95%;">
#    <div style="line-height: 1.6em; font-weight: bold; font-size: 100%; text-align: left;">
#     <div>
#      <style data-mw-deduplicate="TemplateStyles:r886047488">
#       .mw-parser-output .nobold{font-weight:normal}
#      </style>
#      <span class="nobold">
#       17 September 2013
#      </span>
#     </div>
#    </div>
#    <ul class="mw-collapsible-content" style="font-size: 105%; margin-top: 0; margin-bottom: 0; line-height: inherit; text-align: left; list-style: none none; margin-left: 0;">
#     <li style="line-height: inherit; margin: 0">
#      <b>
#       PS3
#      </b>
#      ,
#      <b>
#       Xbox 360
#      </b>
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      17 September 2013
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      <b>
#       PS4
#      </b>
#      ,
#      <b>
#       Xbox One
#      </b>
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      18 November 2014
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      <b>
#       Microsoft Windows
#      </b>
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      14 April 2015
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      <b>
#       PS5
#      </b>
#      ,
#      <b>
#       Xbox Series X/S
#      </b>
#     </li>
#     <li style="line-height: inherit; margin: 0">
#      11 November 2021
#     </li>
#    </ul>
#   </div>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   <a href="/wiki/Video_game_genre" title="Video game genre">
#    Genre(s)
#   </a>
#  </th>
#  <td class="infobox-data">
#   <a class="mw-redirect" href="/wiki/Action-adventure" title="Action-adventure">
#    Action-adventure
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th class="infobox-label" scope="row" style="white-space:nowrap;padding-right:0.65em;">
#   Mode(s)
#  </th>
#  <td class="infobox-data">
#   <a class="mw-redirect" href="/wiki/Single-player" title="Single-player">
#    Single-player
#   </a>
#   ,
#   <a class="mw-redirect" href="/wiki/Multiplayer" title="Multiplayer">
#    multiplayer
#   </a>
#  </td>
# </tr>

# %%
#Creating a function to check for specific conditions in the another function to make the data values
#clean as possible.
def fixing_elems(elem):
    try:
        if elem.find("#mw-content-text > div.mw-parser-output > table > tbody > tr > td"):
            return str(elem.get_text()).split(", ") #This splits long string that are at the same row.
        elif len(elem.find_all("a"))==1:
            return elem.get_text(" ",strip=True) #this checks if an "a" element in each key is single - then to return it not in a form of a list like the other conditions.
        elif elem.select("#mw-content-text > div.mw-parser-output > table.infobox.hproduct > tbody > tr > td > div > div > div"):
            return [el.get_text() for el in elem.select("#mw-content-text > div.mw-parser-output > table.infobox.hproduct > tbody > tr > td > div > div > div")] #This Checks for a specific value locked in a nested div and take the text out.
        elif elem.find("ul",{"class":'mw-collapsible-content hlist'}):
            return elem.a.get_text() #This checks for specific text that is inside a div of a div with no class or id.
        elif elem.select("div.plainlist ul li div.plainlist ul li"):
            elem = [elem.get_text() for elem in elem.select("div.plainlist ul li div.plainlist ul li",limit=3)]
            return elem #This checks for specific text that is above an expandeble list button and take only it.
        elif elem.find("li"):
            return [li.get_text().replace("\xa0","").replace("\n","").strip() for li in elem.find_all("li")] #This create lists and clean them from the "li" elements.
        elif elem.select("#mw-content-text > div.mw-parser-output > table > tbody > tr > td > a"):
            return [text.get_text() for text in elem.select("#mw-content-text > div.mw-parser-output > table > tbody > tr > td > a")] #This split "a" elements that became a long string.
        elif elem.find("b",{"Home versions":""}):
            elem = str(elem)
            elem = elem.replace("Home versions","")
            elem = bs(elem)
            elem = elem.get_text(" ",strip=True).replace("\xa0","").replace("\n","")
            return elem #This delete a specific section of "Home Version" games releases, since I decided to only use the first releases of the games.
        elif elem.find("br"):
            elem = str(elem)
            elem = elem.replace("<br>" , "").replace("\n","").strip()
            elem = bs(elem)
            elem = elem.get_text(", ",strip=True).replace("\xa0","").replace("\n","").split(", ")
            return elem #This deletes line breaks and replace it with a space.
        elif elem:
             return str(elem.get_text().replace("and ","")).split(", ")
        else:
            return elem.get_text(" ",strip=True).replace("\xa0","").replace("\n","").strip() #This return everything else that is fine.
 
    except:
        if elem.find(class_="mw-collapsible mw-collapsed"):  
            pass #This Check for the specific class (mostly of lists I don't need because they are an addition to the information) and skip it.

# %%
def remove_tags(soup):
    for tag in soup.find_all("sup"):
        tag.decompose()

# %%
#Creating a function that takes a URL & and getting the data by each category to a dictionary.
def get_info_box(url):
    r = requests.get(url)
    soups = bs(r.content,"lxml")
    
    remove_tags(soups)
    
    info_box = soups.find(class_="infobox hproduct")
    info_rows = info_box.find_all("tr")
    
    games_info = {}
    for index, row in enumerate(info_rows):
        if index==0:
            games_info["Title"] = row.find("th").get_text(" ",strip=True)
        elif index == 1: # That is the picture, I won't use it.
            continue 
        else:
            key = row.find("th").get_text()
            value = fixing_elems(row.find("td"))
            games_info[key] = value
    
    return games_info
get_info_box("https://en.wikipedia.org/wiki/Dance_Dance_Revolution_(1998_video_game)")
# Out:
# {'Title': 'Dance Dance Revolution',
#  'Developer(s)': ['Konami', 'Bemani'],
#  'Publisher(s)': ['Konami'],
#  'Series': 'Dance Dance Revolution',
#  'Platform(s)': ['Arcade', 'PlayStation'],
#  'Release': ['JP: September 26, 1998',
#   'NA: March 1999',
#   'EU: March 9, 1999',
#   'AS: 1999',
#   'JP: April 10, 1999'],
#  'Genre(s)': ['Music', 'exercise'],
#  'Mode(s)': ['Single-player', 'multiplayer'],
#  'Arcade system': 'Bemani System 573 Analog'}

# %% [markdown]
# # Finish Project Area:

# %%
def remove_tags(soup):
    for tag in soup.find_all("sup"):
        tag.decompose() #This removes all the "span" & "sup" elements.

# %%
#Creating a function to check for specific conditions in the another function to make the data values
#clean as possible.
def fixing_elems(elem):
    try:
        if elem.find("#mw-content-text > div.mw-parser-output > table > tbody > tr > td"):
            return str(elem.get_text().replace("\xa0","").replace("\n","")).split(", ") #This splits long string that are at the same row.
        elif len(elem.find_all("a"))==1:
            return elem.get_text(" ",strip=True).replace("\xa0","").replace("\n","") #this checks if an "a" element in each key is single - then to return it not in a form of a list like the other conditions.
        elif elem.select("#mw-content-text > div.mw-parser-output > table.infobox.hproduct > tbody > tr > td > div > div > div"):
            return [el.get_text().replace("\xa0","").replace("\n","") for el in elem.select("#mw-content-text > div.mw-parser-output > table.infobox.hproduct > tbody > tr > td > div > div > div")] #This Checks for a specific value locked in a nested div and take the text out.
        elif elem.find("ul",{"class":'mw-collapsible-content hlist'}):
            return elem.a.get_text().replace("\xa0","").replace("\n","") #This checks for specific text that is inside a div of a div with no class or id.
        elif elem.select("div.plainlist ul li div.plainlist ul li"):
            elem = [elem.get_text().replace("\xa0","").replace("\n","") for elem in elem.select("div.plainlist ul li div.plainlist ul li",limit=3)]
            return elem #This checks for specific text that is above an expandeble list button and take only it.
        elif elem.find("li"):
            return [li.get_text().replace("\xa0","").replace("\n","").strip() for li in elem.find_all("li")] #This create lists and clean them from the "li" elements.
        elif elem.select("#mw-content-text > div.mw-parser-output > table > tbody > tr > td > a"):
            return [text.get_text().replace("\xa0","").replace("\n","") for text in elem.select("#mw-content-text > div.mw-parser-output > table > tbody > tr > td > a")] #This split "a" elements that became a long string.
        elif elem.find("b",{"Home versions":""}):
            elem = str(elem)
            elem = elem.replace("Home versions","")
            elem = bs(elem)
            elem = elem.get_text(" ",strip=True).replace("\xa0","").replace("\n","")
            return elem #This delete a specific section of "Home Version" games releases, since I decided to only use the first releases of the games.
        elif elem.find("br"):
            elem = str(elem)
            elem = elem.replace("<br>" , "").replace("\n","").strip()
            elem = bs(elem)
            elem = elem.get_text(", ",strip=True).replace("\xa0","").replace("\n","").split(", ")
            return elem #This deletes line breaks and replace it with a space.
        elif elem:
             return str(elem.get_text().replace("and ","")).split(", ").replace("\xa0","").replace("\n","")
        else:
            return elem.get_text(" ",strip=True).replace("\xa0","").replace("\n","").strip() #This return everything else that is fine.
 
    except:
        if elem.find(class_="mw-collapsible mw-collapsed"):  
            pass #This Check for the specific class (mostly of lists I don't need because they are an addition to the information) and skip it.

# %%
#Creating a function that takes a URL & and getting the data by each page link and create dictionaries,
#sorted by the the categories as keys and the values as the keys information.
def get_info_box(url):
    r = requests.get(url)
    soups = bs(r.content,"lxml")
    info_box = soups.find(class_="infobox hproduct")
    info_rows = info_box.find_all("tr")
    
    remove_tags(soups)
    
    games_info = {}
    for index, row in enumerate(info_rows):
        if index==0:
            games_info["Title"] = row.find("th").get_text(" ",strip=True)
        elif index == 1: # That is the picture, I won't use it.
            continue 
        else:
            key = row.find("th").get_text()
            value = fixing_elems(row.find("td"))
            games_info[key] = value
    
    return games_info
# get_info_box("https://en.wikipedia.org/wiki/Donkey_Kong_(video_game)")

# %%
#Loaded the page I'm going to get all the video games list and iterate on each game to get the data
#with the help of the two functions i created above.
r = requests.get("https://en.wikipedia.org/wiki/List_of_video_games_considered_the_best")
soup_games = bs(r.content,"lxml")
games = soup_games.select(".wikitable.sortable i a")

wiki_path = "https://en.wikipedia.org"

game_info_list = []
for index, game in enumerate(games):
    try:
        relative_path = game["href"]
        full_wiki_path = wiki_path+relative_path
        fixing_elems(soup_games)
        title = game["title"]
        game_info_list.append(get_info_box(full_wiki_path))
        
    except Exception as e: #3 games won't open so I decided to pass them.
        pass

# %%
#Cheking the length of the list I created and saw that it has the same length
#without the games number I couldn't iterate.
len(game_info_list)
# Out:
# 236

# %%
#Looked at the first 10 games to see that everything went well.
game_info_list
# Out:
# [{'Title': 'The Oregon Trail',
#   'Developer(s)': ['Don Rawitsch', 'Bill Heinemann', 'Paul Dillenberger'],
#   'Publisher(s)': 'MECC',
#   'Series': 'The Oregon Trail',
#   'Platform(s)': ['Mainframe',
#    'HP 2100',
#    'CDC Cyber 70/73-26',
#    'PC',
#    'Apple II',
#    'Atari 8-Bit',
#    'Commodore 64'],
#   'Release': ['NA: December 3, 1971', 'NA: 1975'],
#   'Genre(s)': 'Strategy',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Pong',
#   'Developer(s)': 'Atari',
#   'Publisher(s)': ['NA/EU: Atari', 'JP: Atari Japan (Namco)'],
#   'Designer(s)': 'Allan Alcorn',
#   'Platform(s)': ['Arcade', 'Various dedicated consoles'],
#   'Release': ['NA: 29 November 1972', 'JP: November 1973', 'EU: 1973'],
#   'Genre(s)': 'Sports',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Zork',
#   'Developer(s)': 'Infocom',
#   'Publisher(s)': ['Personal Software', 'Activision'],
#   'Designer(s)': ['Tim Anderson',
#    'Marc Blank',
#    'Dave Lebling',
#    'Bruce Daniels'],
#   'Engine': 'ZIL',
#   'Platform(s)': ['PDP-10',
#    'Atari 8-bit',
#    'C64',
#    'CP/M',
#    'TRS-80',
#    'IBM PC',
#    'Apple II',
#    'Amiga',
#    'Amstrad CPC',
#    'Amstrad PCW',
#    'Macintosh',
#    'Atari ST',
#    'MS-DOS',
#    'NEC PC-9801',
#    'MSX',
#    'PlayStation',
#    'Sega Saturn',
#    'TI-99/4A',
#    'Commodore Plus/4'],
#   'Release': ['1977 (PDP-10)',
#    '1980 (',
#    'Zork I',
#    ')',
#    '1981 (',
#    'Zork II',
#    ')',
#    '1982 (',
#    'Zork III',
#    ')'],
#   'Genre(s)': 'Text adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Space Invaders',
#   'Developer(s)': 'Taito',
#   'Publisher(s)': ['JP/AS/EU: Taito',
#    'NA/EU: Midway',
#    'AU: Leisure & Allied Industries'],
#   'Designer(s)': 'Tomohiro Nishikado',
#   'Series': 'Space Invaders',
#   'Platform(s)': ['Arcade',
#    'Atari 2600',
#    'Atari 5200',
#    'Atari 8-bit',
#    'MSX',
#    'handheld',
#    'tabletop',
#    'watch',
#    'calculator',
#    'NES',
#    'WonderSwan',
#    'VG Pocket',
#    'mobile',
#    'iOS'],
#   'Release': ['JP: April 1, 1978',
#    'NA: November 1978',
#    'WW: 1978',
#    'NA: March 10, 1980',
#    'EU: 1981'],
#   'Genre(s)': "Shoot 'em up",
#   'Mode(s)': 'Single-player , 2 players alternating',
#   'Arcade system': 'Taito 8080'},
#  {'Title': 'Asteroids',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': ['NA/EU: Atari, Inc.', 'JP: Taito/Sega'],
#   'Designer(s)': ['Lyle Rains', 'Ed Logg'],
#   'Series': 'Asteroids',
#   'Platform(s)': ['Arcade',
#    'Atari 2600',
#    'Atari 7800',
#    'Atari 8-bit',
#    'Game Boy'],
#   'Release': ['NA: November 1979',
#    'EU: 1979',
#    'JP: January 1980',
#    'NA: July 1981',
#    'NA: 1981',
#    'NA: 1986',
#    'NA: 1992'],
#   'Genre(s)': 'Multidirectional shooter',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Adventure',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': ['Atari', 'Inc.'],
#   'Designer(s)': 'Warren Robinett',
#   'Platform(s)': 'Atari 2600',
#   'Release': ['July 1980'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Missile Command',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': ['NA: Atari Inc.',
#    'JP/EU: Sega',
#    'JP: Taito',
#    'NA: Nintendo'],
#   'Designer(s)': 'Dave Theurer',
#   'Programmer(s)': 'Rich Adam Dave Theurer',
#   'Composer(s)': ['Rich Adam'],
#   'Platform(s)': ['Arcade',
#    'Atari 2600',
#    'Atari 5200',
#    'Atari 8-bit',
#    'Atari ST',
#    'Game Boy',
#    'Lynx'],
#   'Release': ['NA: July 1980',
#    'JP: July 1980',
#    'EU: 1980',
#    'NA: April 1981',
#    'NA: 1981',
#    'NA: 1982',
#    'NA: 1987',
#    'NA: 1995',
#    'EU: 1995'],
#   'Genre(s)': "Shoot 'em up",
#   'Mode(s)': ['Up to 2 players', 'alternating turns']},
#  {'Title': 'Pac-Man',
#   'Developer(s)': 'Namco',
#   'Publisher(s)': ['JP/DE: Namco', 'NA/FRA: Midway'],
#   'Designer(s)': 'Toru Iwatani',
#   'Programmer(s)': ['Shigeo Funaki', 'Shigeichi Ishimura'],
#   'Composer(s)': ['Shigeichi Ishimura', 'Toshio Kai'],
#   'Series': 'Pac-Man',
#   'Platform(s)': ['Arcade'],
#   'Release': 'JP : May 22, 1980 WW : December 1980',
#   'Genre(s)': 'Maze',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Centipede',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': ['NA/EU: Atari, Inc.', 'JP: Sanritsu/Kiwako'],
#   'Designer(s)': ['Dona Bailey', 'Ed Logg'],
#   'Programmer(s)': ['Dona Bailey', 'Ed Logg'],
#   'Series': 'Centipede',
#   'Platform(s)': ['Arcade',
#    'Apple II',
#    'Atari 2600',
#    'Atari 5200',
#    'Atari 7800',
#    'Atari 8-bit',
#    'BBC Micro',
#    'ColecoVision',
#    'Commodore 64',
#    'IBM PC',
#    'Intellivision',
#    'TI-99/4A',
#    'VIC-20',
#    'Game Boy'],
#   'Release': ['NA: June 6, 1981',
#    'EU: 1981',
#    'JP: March 1983',
#    'NA: May 3, 1982'],
#   'Genre(s)': 'Fixed shooter',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Defender',
#   'Developer(s)': 'Williams Electronics',
#   'Publisher(s)': ['NA/EU: Williams Electronics', 'JP: Taito'],
#   'Designer(s)': ['Eugene Jarvis', 'Larry DeMar'],
#   'Programmer(s)': ['Eugene Jarvis',
#    'Larry DeMar',
#    'Sam Dicker',
#    'Paul Dussault'],
#   'Platform(s)': ['Arcade',
#    'Apple II',
#    'Atari 2600',
#    'Atari 8-bit',
#    'Atari 5200',
#    'BBC Micro',
#    'ColecoVision',
#    'Commodore 64',
#    'VIC-20',
#    'Intellivision',
#    'TI-99/4A',
#    'IBM PC',
#    'Adventure Vision',
#    'SAM Coupé',
#    'ZX Spectrum'],
#   'Release': ['NA: Early 1981', 'JP: February 1981', 'EU: 1981'],
#   'Genre(s)': 'Scrolling shooter',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Donkey Kong',
#   'Developer(s)': ['Nintendo R&D1', 'Ikegami Tsushinki'],
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Shigeru Miyamoto',
#   'Producer(s)': 'Gunpei Yokoi',
#   'Designer(s)': ['Shigeru Miyamoto', 'Gunpei Yokoi'],
#   'Artist(s)': ['Shigeru Miyamoto'],
#   'Composer(s)': ['Yukio Kaneoka'],
#   'Series': ['Donkey Kong', 'Mario'],
#   'Platform(s)': 'Arcade',
#   'Release': ['JP: July 9, 1981', 'NA: July 31, 1981', 'EU: November 1981'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player',
#   'Arcade system': 'Radar Scope'},
#  {'Title': 'Frogger',
#   'Developer(s)': 'Konami',
#   'Publisher(s)': ['JP/EU: Konami/Sega', 'NA: Sega/Gremlin Industries'],
#   'Series': ['Frogger'],
#   'Platform(s)': ['Arcade'],
#   'Release': ['JP: June 5, 1981', 'NA: September 1981', 'EU: 1981'],
#   'Genre(s)': 'Action',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Galaga',
#   'Developer(s)': 'Namco',
#   'Publisher(s)': ['JP/EU: Namco', 'NA: Midway Manufacturing'],
#   'Director(s)': ['Shigeru Yokoyama'],
#   'Designer(s)': ['Hiroshi Ono'],
#   'Programmer(s)': ['Tetsu Ogawa'],
#   'Composer(s)': ['Nobuyuki Ohnogi'],
#   'Series': 'Galaxian',
#   'Platform(s)': ['Arcade',
#    'SG-1000',
#    'MSX',
#    'Nintendo Entertainment System',
#    'Atari 7800',
#    'Game Boy',
#    'mobile phone',
#    'Xbox 360',
#    'Roku',
#    'iOS',
#    'Xbox One',
#    'PlayStation 4',
#    'Windows'],
#   'Release': ['JP: July 23, 1981', 'EU: 1981', 'NA: October 1981'],
#   'Genre(s)': 'Fixed shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Namco Galaga'},
#  {'Title': 'Tempest',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': 'Atari, Inc.',
#   'Designer(s)': 'Dave Theurer',
#   'Programmer(s)': 'Dave Theurer',
#   'Platform(s)': ['Arcade',
#    'Atari ST',
#    'Amstrad CPC',
#    'BBC Micro',
#    'ZX Spectrum'],
#   'Release': 'October1981 ( 1981-10 ) : Arcade 1985: Spectrum, BBC 1987: Amstrad 1989: Atari ST',
#   'Genre(s)': 'Tube shooter',
#   'Mode(s)': ['Up to 2 players', 'alternating turns']},
#  {'Title': 'Joust',
#   'Developer(s)': ['Williams Electronics', 'Atari, Inc.'],
#   'Publisher(s)': ['Atarisoft', 'Atari Corporation'],
#   'Designer(s)': 'John Newcomer',
#   'Programmer(s)': ['Bill Pfutzenreuter'],
#   'Artist(s)': 'Jan Hendricks Python Anghelo',
#   'Composer(s)': ['Tim Murphy', 'John Kotlarik (sounds)'],
#   'Platform(s)': ['Arcade',
#    'Apple II',
#    'Atari 2600',
#    'Atari 5200',
#    'Atari 7800',
#    'Atari 8-bit',
#    'Lynx',
#    'Atari ST',
#    'IBM PC',
#    'Macintosh',
#    'NES'],
#   'Release': ['NA: July 16, 1982', 'EU: January 1983', 'JP: 1984'],
#   'Genre(s)': 'Action',
#   'Mode(s)': ['Up to 2 players simultaneously']},
#  {'Title': 'Ms. Pac-Man',
#   'Developer(s)': ['General Computer Corporation', 'Midway'],
#   'Publisher(s)': 'Midway',
#   'Designer(s)': ['Steve Golson'],
#   'Composer(s)': ['Chris Rode'],
#   'Series': 'Pac-Man',
#   'Platform(s)': ['Arcade',
#    'Atari 2600',
#    'Atari 5200',
#    'Atari 7800',
#    'Atari 8-bit',
#    'VIC-20',
#    'Commodore 64',
#    'ZX Spectrum',
#    'IBM PC',
#    'Apple II',
#    'TI99-4/A',
#    'Nintendo Entertainment System',
#    'Sega Genesis',
#    'Super Nintendo Entertainment System',
#    'Game Boy',
#    'Game Boy Color'],
#   'Release': 'NA : January 13, 1982',
#   'Genre(s)': 'Maze',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Namco Pac-Man'},
#  {'Title': 'Pitfall!',
#   'Developer(s)': 'Activision',
#   'Publisher(s)': 'Activision',
#   'Designer(s)': 'David Crane',
#   'Platform(s)': ['Atari 2600',
#    'Atari 8-bit',
#    'ColecoVision',
#    'MSX',
#    'C64',
#    'Intellivision',
#    'Apple II'],
#   'Release': 'NA : August 20, 1982',
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Robotron: 2084',
#   'Developer(s)': 'Vid Kidz Shadowsoft (Lynx)',
#   'Publisher(s)': ['Williams Electronics',
#    'Atarisoft',
#    'Atari, Inc.',
#    'Atari Corporation'],
#   'Designer(s)': ['Eugene Jarvis', 'Larry DeMar'],
#   'Programmer(s)': ['Eugene Jarvis', 'Larry DeMar'],
#   'Platform(s)': ['Arcade',
#    'Apple II',
#    'Atari 8-bit',
#    'Atari 5200',
#    'Atari 7800',
#    'Atari ST',
#    'BBC Micro',
#    'Commodore 64',
#    'Lynx',
#    'IBM PC',
#    'VIC-20'],
#   'Release': '1982: Arcade 1983: Apple II, Atari 8-bit, 5200, C64, IBM PC, VIC-20 1985: BBC Micro 1986: Atari 7800 1987: Atari ST 1991: Lynx',
#   'Genre(s)': 'Multidirectional shooter',
#   'Mode(s)': ['1', '2']},
#  {'Title': 'Lode Runner',
#   'Developer(s)': ['Doug Smith', 'Irem', 'Hudson Soft'],
#   'Publisher(s)': ['Broderbund', 'Ariolasoft', 'SystemSoft', 'Irem'],
#   'Programmer(s)': ['Shinichi Nakamoto (NES)'],
#   'Composer(s)': ['Isamu Hirano (NES)'],
#   'Platform(s)': ['Apple II',
#    'Atari 8-bit',
#    'Commodore 64',
#    'VIC-20',
#    'IBM PC',
#    'Arcade',
#    'PC-8801',
#    'SG-1000',
#    'NES',
#    'Pravetz 82/8М',
#    'ZX Spectrum',
#    'MSX',
#    'Atari ST',
#    'PC Engine',
#    'Xbox 360',
#    'Windows',
#    'iPod',
#    'Macintosh',
#    'Virtual Console',
#    'PlayStation 3',
#    'BBC Micro',
#    'PlayStation',
#    'SNES',
#    'Amstrad CPC',
#    'Game Boy',
#    'Amiga'],
#   'Release': ['NA: June 23, 1983',
#    'JP: December 1983',
#    'JP: July 1984',
#    'EU: October 1984',
#    'NA: November 1984',
#    'JP: July 31, 1984',
#    'NA: September 1987'],
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Star Wars',
#   'Developer(s)': 'Atari, Inc.',
#   'Publisher(s)': ['NA/JP/UK: Atari, Inc.', 'SPA: Sega, S.A. SONIC'],
#   'Designer(s)': ['Mike Hally'],
#   'Programmer(s)': ['Greg Rivera', 'Norm Avellar'],
#   'Composer(s)': ['Earl Vickers'],
#   'Series': 'Star Wars',
#   'Platform(s)': 'Arcade',
#   'Release': ['NA: May 5, 1983',
#    'JP: May 1983',
#    'UK: September 1983',
#    'SPA: 1983'],
#   'Genre(s)': 'Rail shooter',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Elite',
#   'Developer(s)': ['David Braben', 'Ian Bell'],
#   'Publisher(s)': ['Acornsoft', 'Firebird', 'Imagineer'],
#   'Composer(s)': ['Johann Strauss', 'David Whittaker'],
#   'Series': 'Elite',
#   'Platform(s)': ['BBC Micro',
#    'Acorn Electron',
#    'Apple II',
#    'Amstrad CPC',
#    'Commodore 64',
#    'ZX Spectrum',
#    'MSX',
#    'Tatung Einstein',
#    'IBM PC compatible',
#    'Acorn Archimedes',
#    'Amiga',
#    'Atari ST',
#    'Nintendo Entertainment System'],
#   'Release': ['20 September 1984'],
#   'Genre(s)': 'Space trading and combat simulator',
#   'Mode(s)': 'Single player'},
#  {'Title': 'Marble Madness',
#   'Developer(s)': ['Atari Games', 'Midway Games'],
#   'Publisher(s)': ['Atari Games'],
#   'Designer(s)': 'Mark Cerny',
#   'Programmer(s)': ['Bob Flanagan'],
#   'Artist(s)': ['Mark Cerny', 'Sam Comstock'],
#   'Composer(s)': 'Brad Fuller Hal Canon',
#   'Platform(s)': ['Arcade',
#    'Amiga',
#    'Apple II',
#    'Apple IIGS',
#    'Atari ST',
#    'C64',
#    'Game Boy',
#    'Game Boy Advance',
#    'Game Gear',
#    'Master System',
#    'Nintendo Entertainment System',
#    'IBM PC',
#    'Genesis',
#    'X68000',
#    'ZX Spectrum'],
#   'Release': 'NA : December 15, 1984',
#   'Genre(s)': ['Platform', 'racing'],
#   'Mode(s)': ['Up to 2 players simultaneously'],
#   'Arcade system': 'Atari System 1'},
#  {'Title': 'Tetris',
#   'Developer(s)': ['Alexey Pajitnov', 'Vladimir Pokhilko'],
#   'Designer(s)': 'Alexey Pajitnov',
#   'Platform(s)': 'List of Tetris variants',
#   'Release': ['USSR: 1984',
#    'USSR: 1986',
#    'EU: November 1987',
#    'NA: January 1988'],
#   'Genre(s)': ['Puzzle', 'tile-matching'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Gauntlet',
#   'Developer(s)': ['Atari Games', 'Tengen'],
#   'Publisher(s)': ['NA/EU: Atari Games', 'JP: Namco'],
#   'Designer(s)': 'Ed Logg',
#   'Programmer(s)': ['Bob Flanagan'],
#   'Artist(s)': ['Sam Comstock',
#    'Susan G. McBride',
#    'Alan J. Murphy',
#    'Will Noble'],
#   'Composer(s)': ['Ben Daglish', 'Tiertex'],
#   'Series': 'Gauntlet',
#   'Platform(s)': ['Arcade',
#    'Amstrad CPC',
#    'Atari ST',
#    'Apple II',
#    'Apple IIGS',
#    'Macintosh',
#    'Commodore 64',
#    'MSX',
#    'Master System',
#    'NES',
#    'Genesis',
#    'ZX Spectrum',
#    'MS-DOS',
#    'PlayStation (console)'],
#   'Release': ['EU: October 15, 1985',
#    'NA: November 1985',
#    'JP: February 1986'],
#   'Genre(s)': ['Hack and slash', 'Dungeon crawl'],
#   'Mode(s)': ['Single-player', '4-player multiplayer'],
#   'Arcade system': 'Atari Gauntlet'},
#  {'Title': "Ghosts 'n Goblins",
#   'Developer(s)': 'Capcom',
#   'Publisher(s)': ['WW: Capcom', 'NA: Taito America'],
#   'Director(s)': 'Tokuro Fujiwara',
#   'Programmer(s)': ['Toshio Arima'],
#   'Artist(s)': ['Masayoshi Kurokawa'],
#   'Composer(s)': ['Ayako Mori'],
#   'Series': "Ghosts 'n Goblins",
#   'Platform(s)': ['Arcade',
#    'Amstrad CPC',
#    'Commodore 64',
#    '16',
#    'MSX',
#    'NES',
#    'ZX Spectrum',
#    'Amiga',
#    'Atari ST',
#    'Game Boy Color',
#    'IBM PC',
#    'Virtual Console',
#    'Android',
#    'iOS'],
#   'Release': ['JP: July 7, 1985',
#    'NA: September 4, 1985',
#    'EU: October 1985',
#    'JP: June 13, 1986',
#    'NA: November 1, 1986',
#    'EU: 1989',
#    'EU: June 1986',
#    'EU: 1986',
#    'UK: 1990'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Super Mario Bros.',
#   'Developer(s)': 'Nintendo R&D4',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Shigeru Miyamoto',
#   'Producer(s)': ['Shigeru Miyamoto'],
#   'Designer(s)': 'Shigeru Miyamoto Takashi Tezuka',
#   'Programmer(s)': ['Toshihiko Nakago', 'Kazuaki Morita'],
#   'Artist(s)': ['Shigeru Miyamoto', 'Takashi Tezuka'],
#   'Composer(s)': 'Koji Kondo',
#   'Series': 'Super Mario',
#   'Platform(s)': ['Nintendo Entertainment System', 'Arcade'],
#   'Release': ['JP: September 13, 1985',
#    'NA: Late 1985',
#    'EU: May 15, 1987',
#    'AU: 1987',
#    'EU: January 1986',
#    'NA: February 1986'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player',
#   'Arcade system': 'Nintendo VS. System'},
#  {'Title': 'Bubble Bobble',
#   'Developer(s)': 'Taito',
#   'Publisher(s)': ['JP: Taito', 'US: Romstar', 'EU: Electrocoin'],
#   'Designer(s)': 'Fukio Mitsuji',
#   'Composer(s)': ['Tadashi Kimijima'],
#   'Series': ['Bubble Bobble'],
#   'Platform(s)': ['Arcade',
#    'Nintendo Entertainment System',
#    'Amiga',
#    'Atari ST',
#    'Commodore 64',
#    'ZX Spectrum',
#    'Amstrad CPC',
#    'Game Boy',
#    'Game Gear',
#    'Sharp X68000',
#    'Game Boy Color',
#    'Sega Master System',
#    'Sega Saturn',
#    'PlayStation'],
#   'Release': ['JP: September 1986',
#    'EU: October 1986',
#    'NA: 1986',
#    'JP: October 30, 1987',
#    'NA: November 7, 1988',
#    'EU: October 26, 1990'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': ['Taito Bubble Bobble']},
#  {'Title': 'The Legend of Zelda',
#   'Developer(s)': 'Nintendo R&D4',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': ['Shigeru Miyamoto', 'Takashi Tezuka'],
#   'Producer(s)': ['Shigeru Miyamoto'],
#   'Designer(s)': ['Takashi Tezuka'],
#   'Programmer(s)': ['Toshihiko Nakago', 'Yasunari Soejima', 'I. Marui'],
#   'Writer(s)': ['Takashi Tezuka', 'Keiji Terui (manual backstory)'],
#   'Composer(s)': 'Koji Kondo',
#   'Series': 'The Legend of Zelda',
#   'Platform(s)': ['Family Computer Disk System',
#    'Nintendo Entertainment System'],
#   'Release': ['February 21, 1986'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Out Run',
#   'Developer(s)': 'Sega',
#   'Publisher(s)': ['WW: Sega (arcade)', 'EU: U.S. Gold (computers)'],
#   'Designer(s)': 'Yu Suzuki',
#   'Composer(s)': 'Hiroshi Kawaguchi',
#   'Series': ['Out Run'],
#   'Platform(s)': ['Arcade',
#    'NEC PC-8801',
#    'Atari ST',
#    'Amiga',
#    'Amstrad CPC',
#    'Commodore 64',
#    'Game Gear',
#    'Genesis',
#    'Master System',
#    'MSX',
#    'PC Engine',
#    'MS-DOS',
#    'Sega Saturn',
#    'ZX Spectrum',
#    'Nintendo 3DS',
#    'Nintendo Switch'],
#   'Release': ['September 1986'],
#   'Genre(s)': 'Driving',
#   'Mode(s)': 'Single-player',
#   'Arcade system': 'Sega OutRun'},
#  {'Title': 'Contra',
#   'Developer(s)': 'Konami',
#   'Publisher(s)': ['Konami'],
#   'Designer(s)': 'Arcade version Koji Hiroshita NES version Shigeharu Umezaki Shinji Kitamoto',
#   'Composer(s)': 'Arcade version Kazuki Muraoka NES/Famicom version Hidenori Maezawa Kiyohiro Sada',
#   'Series': 'Contra',
#   'Platform(s)': ['Arcade, NES/Famicom'],
#   'Release': ['February 20, 1987'],
#   'Genre(s)': 'Run and gun',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Double Dragon',
#   'Developer(s)': ['Technōs Japan'],
#   'Publisher(s)': ['Taito'],
#   'Director(s)': 'Yoshihisa Kishimoto Shinichi Saito',
#   'Producer(s)': ['Yoshihisa Kishimoto'],
#   'Designer(s)': ['Koji Kai', 'Shinichi Saito'],
#   'Programmer(s)': ['Hiroshi Satoh',
#    'Tomoyasu Koga',
#    'Nari Nishimura',
#    'Hideki Kaneda'],
#   'Artist(s)': ['Kumiko Mukai',
#    'Mizuho Yama',
#    'Akemi Tasaki',
#    'Misae Nakaya',
#    'Masato Shiroto'],
#   'Composer(s)': ['Kazunaka Yamane'],
#   'Series': 'Double Dragon',
#   'Platform(s)': ['Arcade'],
#   'Release': ['JP: April 22, 1987',
#    'NA: April 1987',
#    'EU: June 1987',
#    'AU: 1987',
#    'JP: April 8, 1988',
#    'NA: June 24, 1988',
#    'EU: 1990'],
#   'Genre(s)': "Beat 'em up",
#   'Mode(s)': ['Up to 2 players', 'simultaneous'],
#   'Arcade system': ['Custom']},
#  {'Title': 'Punch-Out!!',
#   'Developer(s)': 'Nintendo R&D3',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Genyo Takeda',
#   'Producer(s)': 'Minoru Arakawa',
#   'Designer(s)': ['Kazuo Yoneyama', 'Mayumi Hirota'],
#   'Programmer(s)': ['Masato Hatakeyama'],
#   'Artist(s)': 'Makoto Wada',
#   'Composer(s)': ['Akito Nakatsuka', 'Kenji Yamamoto'],
#   'Series': 'Punch-Out!!',
#   'Platform(s)': ['Famicom/NES', 'Arcade', 'PlayChoice-10'],
#   'Release': ['JP: September 18, 1987',
#    'NA: October 18, 1987',
#    'JP: November 21, 1987'],
#   'Genre(s)': ['Sports', 'fighting'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'R-Type',
#   'Developer(s)': 'Irem',
#   'Publisher(s)': ['JP: Irem', 'NA: Nintendo', 'EU: Electrocoin'],
#   'Producer(s)': ['Kinte'],
#   'Designer(s)': ['Abiko'],
#   'Programmer(s)': ['Sum', 'Misachin'],
#   'Artist(s)': ['Akio', 'Yoshige'],
#   'Composer(s)': ['Masato Ishizaki'],
#   'Series': 'R-Type',
#   'Platform(s)': ['Arcade'],
#   'Release': ['May 15, 1987'],
#   'Genre(s)': 'Side-scrolling shooter',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': ['Irem M72']},
#  {'Title': 'Mega Man 2',
#   'Developer(s)': 'Capcom',
#   'Publisher(s)': ['Capcom'],
#   'Director(s)': 'Akira Kitamura',
#   'Producer(s)': 'Tokuro Fujiwara',
#   'Programmer(s)': ['Nobuyuki Matsushima'],
#   'Artist(s)': 'Yasuaki Kishimoto Naoya Tomita Keiji Inafune Akira Kitamura',
#   'Composer(s)': ['Takashi Tateishi'],
#   'Series': 'Mega Man',
#   'Platform(s)': ['NES/Famicom',
#    'PlayStation',
#    'mobile phones',
#    'iOS',
#    'Android',
#    'Microsoft Windows'],
#   'Release': ['December 24, 1988'],
#   'Genre(s)': ['Action', 'platform'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Ninja Gaiden',
#   'Developer(s)': 'Tecmo',
#   'Publisher(s)': ['Tecmo'],
#   'Director(s)': 'Hideo Yoshizawa',
#   'Artist(s)': 'Masato Kato',
#   'Writer(s)': ['Hideo Yoshizawa'],
#   'Composer(s)': 'Keiji Yamagishi Ryuichi Nitta',
#   'Series': 'Ninja Gaiden',
#   'Platform(s)': ['NES', 'PC Engine', 'Super NES', 'Mobile phone'],
#   'Release': ['JP: December 9, 1988',
#    'NA: March 13, 1989',
#    'PAL: August 15, 1991',
#    'JP: January 24, 1992'],
#   'Genre(s)': ['Platform', 'hack-and-slash'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Super Mario Bros. 3',
#   'Developer(s)': 'Nintendo R&D4',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': ['Shigeru Miyamoto', 'Takashi Tezuka'],
#   'Producer(s)': ['Shigeru Miyamoto'],
#   'Designer(s)': ['Shigeru Miyamoto',
#    'Takashi Tezuka',
#    'Katsuya Eguchi',
#    'Hideki Konno',
#    'Kensuke Tanabe'],
#   'Programmer(s)': ['Toshihiko Nakago'],
#   'Artist(s)': ['Takashi Tezuka',
#    'Hideki Konno',
#    'Hiroyuki Kimura',
#    'Yōichi Kotabe'],
#   'Composer(s)': 'Koji Kondo',
#   'Series': 'Super Mario',
#   'Platform(s)': ['Arcade',
#    'PlayChoice-10',
#    'Nintendo Entertainment System',
#    'Game Boy Advance'],
#   'Release': ['JP: October 23, 1988',
#    'NA: July 15, 1989',
#    'NA: February 12, 1990',
#    'PAL: August 29, 1991'],
#   'Genre(s)': 'Platforming',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Prince of Persia',
#   'Developer(s)': ['Ports'],
#   'Publisher(s)': ['Ports'],
#   'Designer(s)': 'Jordan Mechner',
#   'Composer(s)': ['Mark Cooksey', 'Tommy Tallarico'],
#   'Series': ['Prince of Persia'],
#   'Platform(s)': ['Apple II'],
#   'Release': ['NA: October 3, 1989', 'JP: July 1990', 'EU: September 1990'],
#   'Genre(s)': 'Cinematic platformer',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'SimCity',
#   'Developer(s)': ['Maxis'],
#   'Publisher(s)': ['Maxis'],
#   'Designer(s)': 'Will Wright',
#   'Series': 'SimCity',
#   'Platform(s)': ['Archimedes',
#    'Electron',
#    'Amiga',
#    'Amstrad CPC',
#    'Atari ST',
#    'BBC Micro',
#    'Commodore 64',
#    'CDTV',
#    'DESQview',
#    'MS-DOS',
#    'EPOC32',
#    'FM Towns',
#    'iOS',
#    'J2ME',
#    'Linux',
#    'Mac OS',
#    'OLPC XO-1',
#    'OS/2',
#    'PC-98',
#    'SNES',
#    'Unix',
#    'Windows',
#    'X68000',
#    'ZX Spectrum'],
#   'Release': ['February 2, 1989'],
#   'Genre(s)': 'City-building',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'The Secret of Monkey Island',
#   'Developer(s)': 'Lucasfilm Games',
#   'Publisher(s)': ['NA: Lucasfilm Games', 'EU: U.S. Gold'],
#   'Director(s)': 'Ron Gilbert',
#   'Producer(s)': ['Greg Hammond'],
#   'Designer(s)': ['Ron Gilbert', 'Dave Grossman', 'Tim Schafer'],
#   'Artist(s)': 'Steve Purcell Mark Ferrari Mike Ebert Martin Cameron',
#   'Writer(s)': ['Ron Gilbert', 'Dave Grossman', 'Tim Schafer'],
#   'Composer(s)': 'Michael Land Patrick Mundy',
#   'Series': 'Monkey Island',
#   'Engine': 'SCUMM',
#   'Platform(s)': ['Amiga',
#    'Atari ST',
#    'FM Towns',
#    'Classic Mac OS',
#    'MS-DOS',
#    'Sega CD',
#    'iOS',
#    'Microsoft Windows',
#    'OS X',
#    'PlayStation 3',
#    'Xbox 360'],
#   'Release': ['October 1990'],
#   'Genre(s)': 'Graphic adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Speedball 2: Brutal Deluxe',
#   'Developer(s)': 'The Bitmap Brothers',
#   'Publisher(s)': ['Image Works',
#    'Arena Entertainment',
#    'Empire Interactive',
#    'Akella',
#    'Tower Studios',
#    'SOFEL'],
#   'Designer(s)': ['Eric Matthews'],
#   'Programmer(s)': ['Robert Trevellyan'],
#   'Artist(s)': ['Daniel Malone'],
#   'Composer(s)': 'Nation 12',
#   'Platform(s)': ['Acorn Archimedes',
#    'Atari ST',
#    'Amiga',
#    'Amiga CD32',
#    'Commodore 64',
#    'PC',
#    'Sega Master System',
#    'Game Boy',
#    'Game Boy Advance',
#    'Sega Mega Drive',
#    'Windows Mobile',
#    'PlayStation',
#    'Xbox 360',
#    'iPhone',
#    'Symbian'],
#   'Release': ['1990'],
#   'Genre(s)': ['Sports', 'Action'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Super Mario World',
#   'Developer(s)': 'Nintendo EAD',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Takashi Tezuka',
#   'Producer(s)': 'Shigeru Miyamoto',
#   'Designer(s)': ['Katsuya Eguchi', 'Hideki Konno'],
#   'Programmer(s)': ['Toshihiko Nakago'],
#   'Artist(s)': 'Shigefumi Hino',
#   'Composer(s)': 'Koji Kondo',
#   'Series': 'Super Mario',
#   'Platform(s)': ['Super NES', 'Game Boy Advance'],
#   'Release': ['21 November 1990'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Another World',
#   'Developer(s)': ['Delphine Software', 'Interplay'],
#   'Publisher(s)': ['U.S. Gold', 'Virgin Interactive', 'Headup Games'],
#   'Designer(s)': 'Éric Chahi',
#   'Composer(s)': ['Jean-François Freitas'],
#   'Platform(s)': ['Amiga',
#    'Atari ST',
#    '3DO Interactive Multiplayer',
#    'Atari 800',
#    'Apple IIGS',
#    'Atari Jaguar',
#    'Mac OS',
#    'MS-DOS',
#    'Game Boy Advance',
#    'Sega CD',
#    'Sega Genesis',
#    'Super Nintendo Entertainment System',
#    'iOS',
#    'Linux',
#    'Android',
#    'Microsoft Windows',
#    'Nintendo 3DS',
#    'OS X',
#    'PlayStation 3',
#    'PlayStation 4',
#    'PlayStation Vita',
#    'Symbian',
#    'Wii U',
#    'Windows Mobile',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': ['NA: September 22, 2011',
#    'NA/EU: Cancelled',
#    'WW: December 2013',
#    'WW: July 9, 2018'],
#   'Genre(s)': ['Action-adventure', 'cinematic platformer'],
#   'Mode(s)': ['Single-player']},
#  {'Title': 'Civilization',
#   'Developer(s)': 'MicroProse',
#   'Publisher(s)': 'MicroProse Koei (Super NES)',
#   'Producer(s)': 'Sid Meier',
#   'Designer(s)': 'Sid Meier Bruce Shelley',
#   'Programmer(s)': ['Sid Meier'],
#   'Writer(s)': ['B. C. Milligan',
#    'Jeffery L. Briggs',
#    'Bruce Campbell Shelley'],
#   'Composer(s)': 'Jeffery L. Briggs',
#   'Series': 'Civilization',
#   'Platform(s)': ['MS-DOS',
#    'Amiga',
#    'PC-98',
#    'Atari ST',
#    'Windows',
#    'Macintosh',
#    'Super NES',
#    'Sony PlayStation',
#    'Sega Saturn'],
#   'Release': ['September 1991'],
#   'Genre(s)': 'Turn-based strategy',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'The Legend of Zelda: A Link to the Past',
#   'Developer(s)': 'Nintendo EAD',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Takashi Tezuka',
#   'Producer(s)': 'Shigeru Miyamoto',
#   'Programmer(s)': ['Yasunari Soejima', 'Toshihiko Nakago'],
#   'Artist(s)': ['Masanao Arimoto', 'Tsuyoshi Watanabe'],
#   'Writer(s)': 'Kensuke Tanabe',
#   'Composer(s)': 'Koji Kondo',
#   'Series': 'The Legend of Zelda',
#   'Platform(s)': 'Super Nintendo Entertainment System',
#   'Release': ['JP: November 21, 1991',
#    'NA: April 13, 1992',
#    'EU: September 24, 1992'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Lemmings',
#   'Developer(s)': ['DMA Design',
#    'SunSoft (SNES & GEN)',
#    'Probe Entertainment (GG & MS)',
#    'Psygnosis (CPC, 3DO & Spectrum)',
#    'Ocean Software (NES)'],
#   'Publisher(s)': ['Psygnosis',
#    'Sunsoft (SNES, GEN & NES)',
#    'Sega (GG & MS)',
#    'Atari Corporation (LYNX)',
#    'Ocean Software (GB)',
#    'Philips Media (CD-i)'],
#   'Designer(s)': 'David Jones',
#   'Programmer(s)': 'David Jones Russell Kay Mike Dailly',
#   'Artist(s)': ['Mike Dailly', 'Gary Timmons', 'Scott Johnston'],
#   'Composer(s)': 'Tim Wright Brian Johnston',
#   'Platform(s)': ['Amiga'],
#   'Release': ['14 February 1991'],
#   'Genre(s)': 'Puzzle',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': "Monkey Island 2: LeChuck's Revenge",
#   'Developer(s)': 'LucasArts',
#   'Publisher(s)': ['NA: LucasArts', 'EU: U.S. Gold'],
#   'Director(s)': 'Ron Gilbert',
#   'Producer(s)': 'Shelley Day',
#   'Designer(s)': ['Dave Grossman', 'Tim Schafer'],
#   'Writer(s)': ['Dave Grossman', 'Tim Schafer'],
#   'Composer(s)': ['Michael Land', 'Peter McConnell', 'Clint Bajakian'],
#   'Series': 'Monkey Island',
#   'Engine': 'SCUMM',
#   'Platform(s)': ['Amiga',
#    'FM Towns',
#    'Mac OS',
#    'MS-DOS',
#    'iOS',
#    'Microsoft Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'Xbox One'],
#   'Release': 'Original version December 1991 Special edition 7 July 2010',
#   'Genre(s)': 'Graphic adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Sonic the Hedgehog',
#   'Developer(s)': 'Sonic Team',
#   'Publisher(s)': 'Sega',
#   'Producer(s)': 'Shinobu Toyoda',
#   'Designer(s)': 'Hirokazu Yasuhara',
#   'Programmer(s)': 'Yuji Naka',
#   'Artist(s)': ['Naoto Ohshima', 'Jina Ishiwatari', 'Rieko Kodama'],
#   'Composer(s)': 'Masato Nakamura',
#   'Series': 'Sonic the Hedgehog',
#   'Platform(s)': ['Sega Genesis'],
#   'Release': ['June 23, 1991'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Street Fighter II: The World Warrior',
#   'Developer(s)': 'Capcom Sun L (Game Boy)',
#   'Publisher(s)': 'Capcom Nintendo (Game Boy)',
#   'Producer(s)': 'Yoshiki Okamoto',
#   'Designer(s)': ['Akira Nishitani', 'Akira Yasuda'],
#   'Programmer(s)': ['Shinichi Ueyama',
#    'Seiji Okada',
#    'Yoshihiro Matsui',
#    'Motohide Eshiro'],
#   'Artist(s)': ['Eri Nakamura', 'Satoru Yamashita'],
#   'Composer(s)': 'Yoko Shimomura Isao Abe',
#   'Series': 'Street Fighter',
#   'Platform(s)': ['Arcade'],
#   'Release': ['February 6, 1991'],
#   'Genre(s)': 'Fighting',
#   'Mode(s)': ['Up to 2 players simultaneously'],
#   'Arcade system': 'CP System (CPS-1)'},
#  {'Title': 'Dune II',
#   'Developer(s)': 'Westwood Studios',
#   'Publisher(s)': 'Virgin Games',
#   'Director(s)': ['Aaron E. Powell', 'Lyle J. Hall'],
#   'Producer(s)': 'Brett Sperry',
#   'Designer(s)': ['Joe Bostic', 'Marc Cram', 'Aaron E. Powell'],
#   'Programmer(s)': ['Joseph Bostic', 'Scott K. Bowen'],
#   'Writer(s)': ['Rick Gush', 'Donna J. Bundy', 'Marc Cram'],
#   'Composer(s)': 'Frank Klepacki Dwight Okahara',
#   'Series': 'Dune',
#   'Platform(s)': ['Amiga', 'MS-DOS', 'RISC OS', 'Genesis/Mega Drive'],
#   'Release': ['NA: 1993', 'EU: 1993'],
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Flashback',
#   'Developer(s)': ['Delphine Software International',
#    'Tiertex (SNES, PC-CD, 3DO, CD-i, Jaguar)',
#    'Chui (Dreamcast)'],
#   'Publisher(s)': ['U.S. Gold', 'JoshProd (Dreamcast)', 'Microids (Switch)'],
#   'Designer(s)': 'Paul Cuisset',
#   'Composer(s)': ['Jean Baudlot', 'Raphaël Gesqua', 'Fabrice Visserot'],
#   'Platform(s)': ['Amiga',
#    'Acorn Archimedes',
#    'Mega Drive/Genesis',
#    'MS-DOS',
#    'NEC PC-9801',
#    'Super NES',
#    'Sega CD',
#    'FM Towns',
#    '3DO',
#    'CD-i',
#    'Atari Jaguar',
#    'Mac OS',
#    'iPhone OS',
#    'Symbian',
#    'Maemo',
#    'Dreamcast',
#    'Nintendo Switch',
#    'PlayStation 4'],
#   'Release': ['1992',
#    '1993 (MS-DOS',
#    'SNES',
#    'Acorn Archimedes',
#    'Sega Genesis)',
#    'March 1995 (CD-i)'],
#   'Genre(s)': 'Cinematic platformer',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Mortal Kombat',
#   'Developer(s)': 'Midway',
#   'Publisher(s)': ['Midway'],
#   'Designer(s)': ['Ed Boon', 'John Tobias'],
#   'Programmer(s)': ['Ed Boon'],
#   'Artist(s)': ['John Tobias', 'John Vogel'],
#   'Composer(s)': 'Dan Forden',
#   'Series': 'Mortal Kombat',
#   'Platform(s)': ['Arcade',
#    'Amiga',
#    'Game Boy',
#    'MS-DOS',
#    'Sega CD',
#    'Game Gear',
#    'Genesis',
#    'Master System',
#    'SNES',
#    'TV game',
#    'LCD game'],
#   'Release': ['October 8, 1992'],
#   'Genre(s)': 'Fighting',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Midway Y Unit (Revision Prototype 4.0–Revision 4.0) Midway T Unit (Revision 4.0T–Revision 5.0T)'},
#  {'Title': 'Sonic the Hedgehog 2',
#   'Developer(s)': 'Sega Technical Institute',
#   'Publisher(s)': 'Sega',
#   'Director(s)': ['Masaharu Yoshii'],
#   'Producer(s)': 'Shinobu Toyoda',
#   'Designer(s)': 'Hirokazu Yasuhara Takahiro Anto Yutaka Sugano',
#   'Programmer(s)': 'Yuji Naka Bill Willis Masanobu Yamamoto',
#   'Artist(s)': ['Yasushi Yamaguchi',
#    'Jina Ishiwatari',
#    'Rieko Kodama',
#    'Tim Skelly'],
#   'Composer(s)': 'Masato Nakamura',
#   'Series': 'Sonic the Hedgehog',
#   'Platform(s)': ['Sega Genesis'],
#   'Release': ['November 21, 1992'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Super Mario Kart',
#   'Developer(s)': 'Nintendo EAD',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': ['Tadashi Sugiyama', 'Hideki Konno'],
#   'Producer(s)': 'Shigeru Miyamoto',
#   'Programmer(s)': ['Masato Kimura'],
#   'Artist(s)': ['Yōichi Kotabe', 'Mie Yoshimura', 'Yoshiaki Koizumi'],
#   'Composer(s)': ['Soyo Oka'],
#   'Series': 'Mario Kart',
#   'Platform(s)': 'Super Nintendo Entertainment System',
#   'Release': ['JP: August 27, 1992',
#    'NA: September 1, 1992',
#    'UK: December 1992',
#    'EU: January 21, 1993'],
#   'Genre(s)': 'Kart racing',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Virtua Racing',
#   'Developer(s)': 'Sega AM R&D #2',
#   'Publisher(s)': ['Sega', 'Time Warner Interactive'],
#   'Designer(s)': ['Yu Suzuki'],
#   'Composer(s)': ['Takenobu Mitsuyoshi', 'Naofumi Hataya'],
#   'Platform(s)': ['Arcade', 'Sega Genesis', 'Sega 32X', 'Sega Saturn'],
#   'Release': ['JP: August 1992',
#    'WW: October 1992',
#    'UK: November 1992',
#    'NA: March 14, 1994',
#    'EU: March 16, 1994',
#    'JP: March 18, 1994',
#    'NA: December 12, 1994',
#    'EU: December 14, 1994',
#    'JP: December 16, 1994',
#    'NA: November 6, 1995',
#    'JP: December 22, 1995',
#    'EU: 1996'],
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Sega Model 1'},
#  {'Title': 'Wolfenstein 3D',
#   'Developer(s)': 'id Software',
#   'Publisher(s)': ['Apogee Software', 'FormGen (Spear of Destiny)'],
#   'Director(s)': 'Tom Hall',
#   'Designer(s)': 'John Romero Tom Hall',
#   'Programmer(s)': 'John Carmack John Romero',
#   'Artist(s)': 'Adrian Carmack',
#   'Composer(s)': 'Robert Prince (DOS) Brian Luzietti (Macintosh) Todd Dennis (3DO)',
#   'Series': 'Wolfenstein',
#   'Platform(s)': ['DOS',
#    'Arcade (VR)',
#    'PC-98',
#    'SNES',
#    'Jaguar',
#    'Classic Mac OS',
#    'Acorn Archimedes',
#    '3DO',
#    'Apple IIGS',
#    'Game Boy Advance',
#    'Xbox',
#    'Linux',
#    'iOS',
#    'Xbox 360',
#    'PlayStation 3 (PSN)',
#    'Android'],
#   'Release': ['May\xa05,\xa01992\xa0(1992-05-05)'],
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Day of the Tentacle',
#   'Developer(s)': 'LucasArts',
#   'Publisher(s)': ['LucasArts'],
#   'Director(s)': ['Dave Grossman', 'Tim Schafer'],
#   'Producer(s)': ['Dave Grossman', 'Tim Schafer'],
#   'Designer(s)': ['Tim Schafer', 'Dave Grossman'],
#   'Artist(s)': 'Peter Chan',
#   'Writer(s)': ['Tim Schafer', 'Dave Grossman', 'Ron Gilbert', 'Gary Winnick'],
#   'Composer(s)': ['Clint Bajakian', 'Peter McConnell', 'Michael Land'],
#   'Engine': 'SCUMM',
#   'Platform(s)': ['MS-DOS',
#    'Mac OS',
#    'Microsoft Windows',
#    'OS X',
#    'PlayStation 4',
#    'PlayStation Vita',
#    'iOS',
#    'Linux',
#    'Xbox One'],
#   'Release': 'June 25, 1993 MS-DOS , Mac OS NA : June 25, 1993 Win , OS X , PS4 , Vita WW : March 22, 2016 iOS , Linux WW : July 11, 2016 Xbox One WW : October 29, 2020',
#   'Genre(s)': 'Graphic adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Daytona USA',
#   'Developer(s)': 'Sega AM2',
#   'Publisher(s)': 'Sega',
#   'Director(s)': 'Toshihiro Nagoshi',
#   'Producer(s)': 'Toshihiro Nagoshi Yu Suzuki',
#   'Designer(s)': ['Makoto Osaki', 'Yukinobu Arikawa'],
#   'Programmer(s)': ['Daichi Katagiri', 'Koki Koiwa', 'Hideomi Miyauchi'],
#   'Composer(s)': 'Takenobu Mitsuyoshi',
#   'Series': ['Daytona USA'],
#   'Platform(s)': ['Arcade',
#    'Sega Saturn',
#    'Windows',
#    'PlayStation 3',
#    'PSN',
#    'Xbox 360',
#    'XBLA'],
#   'Release': 'JP : March 1994 WW : April 1994',
#   'Genre(s)': 'Racing',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Sega Model 2'},
#  {'Title': 'Doom',
#   'Developer(s)': 'id Software',
#   'Publisher(s)': ['id Software'],
#   'Designer(s)': ['John Romero', 'Tom Hall', 'Sandy Petersen'],
#   'Programmer(s)': ['John Carmack', 'John Romero', 'Dave Taylor'],
#   'Artist(s)': ['Adrian Carmack', 'Kevin Cloud'],
#   'Composer(s)': 'Robert Prince',
#   'Series': 'Doom',
#   'Engine': 'id Tech 1',
#   'Platform(s)': ['MS-DOS'],
#   'Release': ['December 10, 1993'],
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': "The Legend of Zelda: Link's Awakening",
#   'Developer(s)': 'Nintendo EAD',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Takashi Tezuka',
#   'Producer(s)': 'Shigeru Miyamoto',
#   'Designer(s)': ['Yasuhisa Yamamura'],
#   'Programmer(s)': ['Takamitsu Kuzuhara', 'Kazuaki Morita'],
#   'Artist(s)': ['Yoichi Kotabe', 'Masanao Arimoto', 'Shigefumi Hino'],
#   'Writer(s)': ['Yoshiaki Koizumi', 'Kensuke Tanabe'],
#   'Composer(s)': 'Kazumi Totaka Minako Hamano Kozue Ishikawa',
#   'Series': 'The Legend of Zelda',
#   'Platform(s)': ['Game Boy', 'Game Boy Color'],
#   'Release': ['NA: December 15, 1998'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Mortal Kombat II',
#   'Developer(s)': ['Midway',
#    'Probe Entertainment',
#    'Sculptured Software',
#    'Sony Online Entertainment',
#    'Digital Eclipse',
#    'Backbone Entertainment'],
#   'Publisher(s)': ['Acclaim Entertainment', 'home versions'],
#   'Producer(s)': ['Ken Fedesna', 'Neil Nicastro'],
#   'Designer(s)': ['Ed Boon', 'John Tobias'],
#   'Programmer(s)': ['Ed Boon'],
#   'Artist(s)': ['John Tobias', 'Tony Goskie', 'John Vogel'],
#   'Composer(s)': 'Dan Forden Matt Furniss (Sega Genesis, Game Gear, Master System)',
#   'Series': 'Mortal Kombat',
#   'Platform(s)': ['Arcade',
#    'Game Gear',
#    'Genesis/Mega Drive',
#    'SNES',
#    'Game Boy',
#    '32X',
#    'Amiga',
#    'Master System',
#    'MS-DOS',
#    'Saturn',
#    'PlayStation',
#    'PlayStation Network'],
#   'Release': ['NA: June 25, 1993',
#    'NA: September 9, 1994',
#    'EU: 1994',
#    'NA: October 27, 1994',
#    'EU: October 27, 1994',
#    'NA: December 4, 1994',
#    'EU: 1994',
#    'JP: May 19, 1995',
#    'NA: 1994',
#    'EU: 1994',
#    'EU: 1994',
#    'NA: May 16, 1995',
#    'EU: 1995',
#    'NA: March 28, 1996',
#    'EU: 1996',
#    'JP: March 29, 1996',
#    'JP: August 2, 1996',
#    'NA: April 12, 2007',
#    'EU: June 8, 2007'],
#   'Genre(s)': 'Fighting game',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Midway T Unit'},
#  {'Title': 'Myst',
#   'Developer(s)': ['Cyan'],
#   'Publisher(s)': ['Broderbund'],
#   'Producer(s)': ['Laurie Strand'],
#   'Designer(s)': ['Rand Miller', 'Robyn Miller'],
#   'Artist(s)': 'Robyn Miller Chuck Carter',
#   'Composer(s)': ['Robyn Miller'],
#   'Series': 'Myst',
#   'Platform(s)': ['Mac OS',
#    'Saturn',
#    'PlayStation',
#    '3DO',
#    'Microsoft Windows',
#    'Atari Jaguar CD',
#    'CD-i',
#    'AmigaOS',
#    'Pocket PC',
#    'PlayStation Portable',
#    'Nintendo DS',
#    'iOS',
#    'Nintendo 3DS',
#    'Android',
#    'Oculus Quest',
#    'Oculus Quest 2',
#    'Nintendo Switch'],
#   'Release': ['NA: September 24, 1993',
#    'NA: 1994',
#    'NA: March 17, 1995',
#    'NA: September, 1995',
#    'PAL: September, 1995',
#    'NA: December 14, 1995',
#    'PAL: 1995',
#    'NA: September 30, 1996',
#    'PAL: November 15, 1996'],
#   'Genre(s)': ['Graphic adventure', 'puzzle'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'NBA Jam',
#   'Developer(s)': ['Midway', 'Iguana'],
#   'Publisher(s)': ['Midway', 'Acclaim Entertainment'],
#   'Designer(s)': ['Mark Turmell',
#    'Shawn Liptak',
#    'Jamie Rivett',
#    'Sal Divita',
#    'John Carlton',
#    'Tony Goskie'],
#   'Composer(s)': ['Jon Hey', '(Arcade)', 'Rick Fox', '(Genesis/SNES)'],
#   'Series': 'NBA Jam',
#   'Platform(s)': ['Arcade',
#    'Super NES',
#    'Sega Genesis',
#    'Game Gear',
#    'Game Boy',
#    'Sega CD',
#    'Sega Saturn'],
#   'Release': ['NA: April 1993',
#    'NA: March 4, 1994',
#    'EU: 1994',
#    'JP: April 29, 1994',
#    'NA: November 1994',
#    'EU: November 24, 1994',
#    'JP: 1994',
#    'NA: 1994',
#    'EU: 1994',
#    'JP: December 20, 1994',
#    'NA: February 23, 1995',
#    'EU: February 23, 1995',
#    'JP: February 24, 1995'],
#   'Genre(s)': ['Sports', 'basketball'],
#   'Mode(s)': ['Up to 4 players simultaneously'],
#   'Arcade system': 'Midway T Unit'},
#  {'Title': 'Phantasy Star IV',
#   'Developer(s)': 'Sega',
#   'Publisher(s)': ['Sega'],
#   'Director(s)': 'Rieko Kodama Toru Yoshida Kiyoshi Takeuchi',
#   'Producer(s)': ['Jerry Markota'],
#   'Artist(s)': ['Toru Yoshida'],
#   'Writer(s)': 'Akinori Nishiyama Toru Yoshida',
#   'Composer(s)': ['Izuho Numata', 'Masaki Nakagaki'],
#   'Series': 'Phantasy Star',
#   'Platform(s)': 'Sega Genesis',
#   'Release': ['JP: December 17, 1993',
#    'NA: February 1995',
#    'EU: December 8, 1995'],
#   'Genre(s)': 'Role-playing video game',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Sam & Max Hit the Road',
#   'Developer(s)': 'LucasArts',
#   'Publisher(s)': 'LucasArts',
#   'Director(s)': ['Sean Clark', 'Mike Stemmle'],
#   'Producer(s)': ['Sean Clark', 'Mike Stemmle'],
#   'Designer(s)': 'Sean Clark Collette Michaud Steve Purcell Michael Stemmle',
#   'Programmer(s)': ['Sean Clark',
#    'Michael Stemmle',
#    'Livia Macklin',
#    'Jonathan Ackley'],
#   'Composer(s)': ['Clint Bajakian', 'Peter McConnell', 'Michael Z. Land'],
#   'Series': 'Sam & Max',
#   'Engine': ['SCUMM', 'iMUSE'],
#   'Platform(s)': ['MS-DOS', 'Mac OS', 'Microsoft Windows'],
#   'Release': ['November 1993'],
#   'Genre(s)': 'Graphic adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Secret of Mana',
#   'Developer(s)': 'Square',
#   'Publisher(s)': ['Square'],
#   'Director(s)': 'Koichi Ishii',
#   'Producer(s)': 'Hiromichi Tanaka',
#   'Designer(s)': ['Koichi Ishii', 'Hiromichi Tanaka'],
#   'Programmer(s)': 'Nasir Gebelli',
#   'Artist(s)': 'Shinichi Kameoka Hiroo Isono',
#   'Writer(s)': ['Hiromichi Tanaka'],
#   'Composer(s)': 'Hiroki Kikuta',
#   'Series': 'Mana',
#   'Platform(s)': ['Super NES',
#    'FOMA 903i/703i',
#    'iOS',
#    'Android',
#    'Microsoft Windows',
#    'PlayStation 4',
#    'PlayStation Vita'],
#   'Release': ['August 6, 1993'],
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'SimCity 2000',
#   'Developer(s)': ['Maxis'],
#   'Publisher(s)': ['Maxis'],
#   'Designer(s)': ['Will Wright', 'Fred Haslam'],
#   'Artist(s)': ['Jenny Martin',
#    'Suzie Greene',
#    'Kelli Pearson',
#    'Eben Sorkin'],
#   'Composer(s)': ['Sue Kasper', 'Brian Conrad', 'Justin McCormick'],
#   'Series': 'SimCity',
#   'Platform(s)': ['Mac OS',
#    'MS-DOS',
#    'Amiga',
#    'SNES',
#    'Sega Saturn',
#    'PlayStation',
#    'Nintendo 64',
#    'Game Boy Advance',
#    'Windows Mobile'],
#   'Release': ['1993'],
#   'Genre(s)': 'City-building',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Star Fox',
#   'Developer(s)': ['Nintendo EAD', 'Argonaut Software'],
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Katsuya Eguchi',
#   'Producer(s)': 'Shigeru Miyamoto',
#   'Designer(s)': 'Shigeru Miyamoto',
#   'Programmer(s)': ['Dylan Cuthbert', 'Giles Goddard'],
#   'Artist(s)': 'Takaya Imamura',
#   'Composer(s)': ['Hajime Hirasawa'],
#   'Series': 'Star Fox',
#   'Platform(s)': 'SNES',
#   'Release': ['JP: 21 February 1993', 'NA: 26 March 1993', 'EU: 3 June 1993'],
#   'Genre(s)': ['Rail shooter', "shoot 'em up"],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Syndicate',
#   'Developer(s)': 'Bullfrog Productions',
#   'Publisher(s)': ['Electronic Arts'],
#   'Producer(s)': 'Peter Molyneux (Bullfrog) Kevin Buckner (EA)',
#   'Designer(s)': ['Sean Cooper'],
#   'Programmer(s)': ['Sean Cooper', 'Phillip Jones'],
#   'Artist(s)': ['Chris Hill', 'Paul McLaughlin'],
#   'Composer(s)': 'Russell Shaw',
#   'Series': 'Syndicate',
#   'Platform(s)': ['MS-DOS',
#    'Amiga',
#    'Amiga CD32',
#    'Mac',
#    'Sega Genesis',
#    'SNES',
#    'FM Towns',
#    'NEC PC-9801',
#    'Atari Jaguar',
#    '3DO',
#    'Sega-CD',
#    'Acorn Archimedes'],
#   'Release': ['June 6', '1993'],
#   'Genre(s)': 'Real-time tactics',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Donkey Kong Country',
#   'Developer(s)': 'Rare',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': ['Tim Stamper', 'Chris Stamper'],
#   'Designer(s)': 'Gregg Mayles',
#   'Programmer(s)': ['Chris Sutherland'],
#   'Artist(s)': 'Steve Mayles Kevin Bayliss Mark Stevenson Adrian Smith',
#   'Writer(s)': 'Gregg Mayles Daniel Owsen',
#   'Composer(s)': ['David Wise', 'Eveline Fischer', 'Robin Beanland'],
#   'Series': 'Donkey Kong',
#   'Platform(s)': ['Super Nintendo Entertainment System',
#    'Game Boy Color',
#    'Game Boy Advance'],
#   'Release': ['UK: 18 November 1994',
#    'NA: 21 November 1994',
#    'EU: 24 November 1994'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Doom II',
#   'Developer(s)': 'id Software',
#   'Publisher(s)': 'GT Interactive Software',
#   'Designer(s)': ['Sandy Petersen', 'Shawn Green', 'American McGee'],
#   'Programmer(s)': ['John Carmack', 'John Romero', 'Dave Taylor'],
#   'Artist(s)': ['Adrian Carmack', 'Kevin Cloud'],
#   'Composer(s)': 'Robert Prince',
#   'Series': 'Doom',
#   'Engine': 'id Tech 1',
#   'Platform(s)': ['MS-DOS'],
#   'Release': ['October 10, 1994'],
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'EarthBound',
#   'Developer(s)': ['Ape', 'HAL Laboratory'],
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Shigesato Itoi',
#   'Producer(s)': ['Satoru Iwata', 'Tsunekazu Ishihara'],
#   'Designer(s)': ['Akihiko Miura'],
#   'Programmer(s)': ['Satoru Iwata', 'Kouji Malta'],
#   'Artist(s)': ['Kouichi Ooyama'],
#   'Writer(s)': ['Shigesato Itoi'],
#   'Composer(s)': ['Keiichi Suzuki', 'Hirokazu Tanaka'],
#   'Series': 'Mother',
#   'Platform(s)': ['Super NES', 'Game Boy Advance'],
#   'Release': ['JP: August 27, 1994', 'NA: June 5, 1995'],
#   'Genre(s)': 'Role-playing',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Final Fantasy VI',
#   'Developer(s)': 'Square',
#   'Publisher(s)': ['Square'],
#   'Director(s)': ['Yoshinori Kitase', 'Hiroyuki Ito'],
#   'Producer(s)': 'Hironobu Sakaguchi',
#   'Designer(s)': ['Hiroyuki Ito'],
#   'Artist(s)': ['Tetsuya Takahashi',
#    'Kazuko Shibuya',
#    'Yoshitaka Amano',
#    'Hideo Minaba',
#    'Tetsuya Nomura'],
#   'Writer(s)': ['Yoshinori Kitase', 'Hironobu Sakaguchi'],
#   'Composer(s)': 'Nobuo Uematsu',
#   'Series': 'Final Fantasy',
#   'Platform(s)': ['Super Nintendo Entertainment System'],
#   'Release': ['April 2, 1994'],
#   'Genre(s)': 'Role-playing',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Sega Rally Championship',
#   'Developer(s)': 'Sega AM3',
#   'Publisher(s)': 'Sega',
#   'Director(s)': ['Kenji Sasaki'],
#   'Producer(s)': 'Tetsuya Mizuguchi',
#   'Programmer(s)': ['Sohei Yamamoto'],
#   'Artist(s)': ['Kenji Sasaki'],
#   'Composer(s)': 'Takenobu Mitsuyoshi',
#   'Series': ['Sega Rally'],
#   'Platform(s)': ['Arcade',
#    'Sega Saturn',
#    'Windows',
#    'N-Gage',
#    'Game Boy Advance'],
#   'Release': ['October 11, 1994'],
#   'Genre(s)': 'Racing game',
#   'Mode(s)': ['Single-player', 'multiplayer'],
#   'Arcade system': 'Sega Model 2'},
#  {'Title': 'Sensible World of Soccer',
#   'Developer(s)': 'Sensible Software',
#   'Publisher(s)': ['Renegade', 'GT Interactive', 'Codemasters', 'Microsoft'],
#   'Designer(s)': ['Jon Hare', 'Sensible Software'],
#   'Programmer(s)': ['Chris Chapman'],
#   'Artist(s)': 'Jon Hare Stoo Cambridge',
#   'Composer(s)': ['Jon Hare', 'Richard Joseph'],
#   'Platform(s)': ['Amiga', 'MS-DOS', 'Xbox 360'],
#   'Release': ['1994',
#    "1995 (Edition '95/'96)",
#    "1996 (ECE and '96/'97)",
#    '2007 (Xbox 360)'],
#   'Genre(s)': ['Sports', 'sports management'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Star Wars: TIE Fighter',
#   'Developer(s)': 'Totally Games',
#   'Publisher(s)': 'LucasArts',
#   'Designer(s)': 'Lawrence Holland Edward Kilham',
#   'Composer(s)': 'Peter McConnell',
#   'Series': ['Star Wars: X-Wing'],
#   'Platform(s)': ['DOS', 'Macintosh', 'Microsoft Windows'],
#   'Release': ['July 1994'],
#   'Genre(s)': 'Space simulation',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Super Metroid',
#   'Developer(s)': ['Nintendo R&D1', 'Intelligent Systems'],
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Yoshio Sakamoto',
#   'Producer(s)': 'Makoto Kano',
#   'Programmer(s)': ['Kenji Imai'],
#   'Artist(s)': 'Hirofumi Matsuoka Masahiko Mashimo Hiroyuki Kimura',
#   'Composer(s)': 'Kenji Yamamoto Minako Hamano',
#   'Series': 'Metroid',
#   'Platform(s)': 'Super Nintendo Entertainment System',
#   'Release': ['JP: March 19, 1994',
#    'NA: April 18, 1994',
#    'PAL: July 28, 1994'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'X-COM: UFO Defense',
#   'Developer(s)': ['Mythos Games', 'MicroProse'],
#   'Publisher(s)': ['MicroProse'],
#   'Producer(s)': ['Tim Roberts'],
#   'Designer(s)': 'Julian Gollop Nick Gollop',
#   'Programmer(s)': ['Julian Gollop', 'Nick Gollop'],
#   'Artist(s)': ['Julian Gollop', 'John Reitze', 'Martin Smillie'],
#   'Composer(s)': 'John Broomhall',
#   'Series': 'X-COM',
# ...
#   'Director(s)': 'Casey Hudson',
#   'Producer(s)': ['Jesse Houston', 'Nathan Plewes'],
#   'Designer(s)': ['Preston Watamaniuk'],
#   'Programmer(s)': ['David Falkner'],
#   'Artist(s)': ['Derek Watts'],
#   'Writer(s)': 'Mac Walters Drew Karpyshyn',
#   'Composer(s)': ['Jack Wall', 'Jimmy Hinson', 'Sam Hulick', 'David Kates'],
#   'Series': 'Mass Effect',
#   'Engine': 'Unreal Engine 3',
#   'Platform(s)': ['Microsoft Windows', 'Xbox 360', 'PlayStation 3'],
#   'Release': ['January 26, 2010'],
#   'Genre(s)': ['Action role-playing', 'third-person shooter'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Red Dead Redemption',
#   'Developer(s)': 'Rockstar San Diego',
#   'Publisher(s)': 'Rockstar Games',
#   'Producer(s)': ['Steve Martin', 'Josh Needleman', 'David Kunkler'],
#   'Designer(s)': ['Christian Cantamessa', 'Leslie Benzies'],
#   'Programmer(s)': ['Ted Carson'],
#   'Artist(s)': ['Joshua Bass', 'Daren Bader', 'Nick Trifunovic'],
#   'Writer(s)': 'Dan Houser Michael Unsworth Christian Cantamessa',
#   'Composer(s)': 'Bill Elm Woody Jackson',
#   'Series': 'Red Dead',
#   'Engine': 'RAGE',
#   'Platform(s)': ['PlayStation 3', 'Xbox 360'],
#   'Release': ['NA: May 18, 2010', 'PAL: May 21, 2010'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Rock Band 3',
#   'Developer(s)': 'Harmonix',
#   'Publisher(s)': ['MTV Games', 'Mad Catz'],
#   'Designer(s)': ['Dan Teasdale',
#    'Sylvain Dubrofsky',
#    'Brian Chan',
#    'Casey Malone'],
#   'Series': 'Rock Band',
#   'Platform(s)': ['Xbox 360', 'PlayStation 3', 'Wii', 'Nintendo DS'],
#   'Release': ['NA: October 26, 2010',
#    'AU: October 28, 2010',
#    'EU: October 29, 2010'],
#   'Genre(s)': 'Music video game',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'StarCraft II: Wings of Liberty',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': ['Blizzard Entertainment'],
#   'Producer(s)': ['Chris Sigaty'],
#   'Designer(s)': 'Dustin Browder',
#   'Programmer(s)': ['Carl Chimes', 'Bob Fitch'],
#   'Artist(s)': 'Samwise Didier',
#   'Writer(s)': 'Chris Metzen Andrew Chambers Brian Kindregan',
#   'Composer(s)': ['Russell Brower', 'Neal Acree'],
#   'Series': 'StarCraft',
#   'Engine': ['In-house'],
#   'Platform(s)': ['Microsoft Windows', 'macOS'],
#   'Release': ['July 27', '2010'],
#   'Genre(s)': 'Real-time strategy',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Super Mario Galaxy 2',
#   'Developer(s)': 'Nintendo EAD Tokyo',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': ['Koichi Hayashida'],
#   'Producer(s)': ['Yoshiaki Koizumi', 'Takashi Tezuka'],
#   'Designer(s)': ['Kenta Motokura'],
#   'Programmer(s)': ['Takeshi Hayakawa'],
#   'Artist(s)': ['Daisuke Watanabe'],
#   'Composer(s)': ['Mahito Yokota', 'Ryo Nagamatsu', 'Koji Kondo'],
#   'Series': 'Super Mario',
#   'Platform(s)': 'Wii',
#   'Release': ['NA: May 23, 2010',
#    'JP: May 27, 2010',
#    'EU: June 11, 2010',
#    'AU: July 1, 2010'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Super Meat Boy',
#   'Developer(s)': ['Team Meat'],
#   'Publisher(s)': ['Team Meat'],
#   'Producer(s)': ['Kevin Hathaway'],
#   'Designer(s)': ['Edmund McMillen', 'Tommy Refenes'],
#   'Programmer(s)': ['Tommy Refenes'],
#   'Artist(s)': ['Edmund McMillen'],
#   'Composer(s)': 'Danny Baranowsky',
#   'Platform(s)': ['Xbox 360',
#    'Microsoft Windows',
#    'OS X',
#    'Linux',
#    'PlayStation 4',
#    'PlayStation Vita',
#    'Wii U',
#    'Nintendo Switch'],
#   'Release': ['October 20, 2010'],
#   'Genre(s)': 'Platform',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Batman: Arkham City',
#   'Developer(s)': 'Rocksteady Studios',
#   'Publisher(s)': 'Warner Bros. Interactive Entertainment',
#   'Director(s)': 'Sefton Hill',
#   'Producer(s)': ['Daniel Bailie', 'Nathan Burlow'],
#   'Programmer(s)': ['Ben Wyatt'],
#   'Artist(s)': ['David Hego'],
#   'Writer(s)': 'Paul Dini Paul Crocker Sefton Hill',
#   'Composer(s)': 'Nick Arundel Ron Fish',
#   'Series': 'Batman: Arkham',
#   'Engine': 'Unreal Engine 3',
#   'Platform(s)': ['PlayStation 3',
#    'Xbox 360',
#    'Microsoft Windows',
#    'Wii U',
#    'OS X',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': ['October 18, 2011'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Dark Souls',
#   'Developer(s)': 'FromSoftware',
#   'Publisher(s)': ['JP: FromSoftware'],
#   'Director(s)': 'Hidetaka Miyazaki',
#   'Producer(s)': ['Hidetaka Miyazaki', 'Daisuke Uchiyama', 'Kei Hirono'],
#   'Programmer(s)': ['Jun Ito'],
#   'Artist(s)': ['Makoto Sato'],
#   'Composer(s)': 'Motoi Sakuraba',
#   'Series': 'Souls',
#   'Platform(s)': ['PlayStation 3',
#    'Xbox 360',
#    'Microsoft Windows',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': ['September 22, 2011'],
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'The Elder Scrolls V: Skyrim',
#   'Developer(s)': 'Bethesda Game Studios',
#   'Publisher(s)': 'Bethesda Softworks',
#   'Director(s)': 'Todd Howard',
#   'Producer(s)': ['Ashley Cheng', 'Craig Lafferty'],
#   'Designer(s)': ['Bruce Nesmith', 'Kurt Kuhlmann', 'Emil Pagliarulo'],
#   'Programmer(s)': ['Guy Carver'],
#   'Artist(s)': ['Matthew Carofano'],
#   'Writer(s)': ['Emil Pagliarulo'],
#   'Composer(s)': 'Jeremy Soule',
#   'Series': 'The Elder Scrolls',
#   'Engine': 'Creation Engine',
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': ['PC, PS3, Xbox 360',
#    'November 11, 2011',
#    'PS4, Xbox One',
#    'October 28, 2016',
#    'Nintendo Switch',
#    'November 17, 2017'],
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Minecraft',
#   'Developer(s)': 'Mojang Studios',
#   'Publisher(s)': ['Mojang Studios',
#    'Microsoft Studios',
#    'Sony Interactive Entertainment'],
#   'Designer(s)': ['Markus Persson', 'Jens Bergensten'],
#   'Artist(s)': ['Markus Toivonen', 'Jasper Boerstra'],
#   'Composer(s)': 'C418',
#   'Series': 'Minecraft',
#   'Platform(s)': ['Windows, macOS, Linux'],
#   'Release': ['18 November 2011'],
#   'Genre(s)': ['Sandbox', 'survival'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Portal 2',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Director(s)': ['Joshua Weier'],
#   'Producer(s)': 'Gabe Newell',
#   'Artist(s)': ['Jeremy Bennett', 'Randy Lundeen'],
#   'Writer(s)': ['Erik Wolpaw', 'Jay Pinkerton', 'Chet Faliszek'],
#   'Composer(s)': 'Mike Morasky',
#   'Series': 'Portal',
#   'Engine': 'Source',
#   'Platform(s)': ['Windows', 'Mac OS X', 'Linux', 'PlayStation 3', 'Xbox 360'],
#   'Release': ['April 18, 2011'],
#   'Genre(s)': 'Puzzle-platform',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Dishonored',
#   'Developer(s)': 'Arkane Studios',
#   'Publisher(s)': 'Bethesda Softworks',
#   'Director(s)': ['Raphaël Colantonio', 'Harvey Smith'],
#   'Programmer(s)': ['Hugues Tardif', 'Stevan Hird'],
#   'Artist(s)': ['Sébastien Mitton'],
#   'Writer(s)': ['Harvey Smith', 'Austin Grossman', 'Terri Brosius'],
#   'Composer(s)': 'Daniel Licht',
#   'Series': 'Dishonored',
#   'Engine': 'Unreal Engine 3',
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 3',
#    'Xbox 360',
#    'PlayStation 4',
#    'Xbox One'],
#   'Release': ['9 October 2012'],
#   'Genre(s)': ['Action-adventure', 'stealth'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Journey',
#   'Developer(s)': ['Thatgamecompany', 'Santa Monica Studio'],
#   'Publisher(s)': ['Sony Computer Entertainment',
#    'Annapurna Interactive (PC, iOS)'],
#   'Director(s)': 'Jenova Chen',
#   'Producer(s)': 'Robin Hunicke',
#   'Designer(s)': ['Nicholas Clark', 'Bryan Singh', 'Chris Bell'],
#   'Programmer(s)': ['John Edwards', 'Martin Middleton'],
#   'Artist(s)': ['Matt Nava', 'Aaron Jessie'],
#   'Composer(s)': 'Austin Wintory',
#   'Engine': 'PhyreEngine',
#   'Platform(s)': ['PlayStation 3',
#    'PlayStation 4',
#    'Microsoft Windows',
#    'iOS'],
#   'Release': ['NA: March 13, 2012', 'EU: March 14, 2012', 'NA: July 21, 2015'],
#   'Genre(s)': ['Adventure', 'art game'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Hotline Miami',
#   'Developer(s)': 'Dennaton Games',
#   'Publisher(s)': 'Devolver Digital',
#   'Designer(s)': 'Jonatan Söderström Dennis Wedin',
#   'Programmer(s)': ['Jonatan Söderström'],
#   'Artist(s)': ['Dennis Wedin'],
#   'Writer(s)': ['Jonatan Söderström', 'Dennis Wedin'],
#   'Engine': ['Game Maker 7', 'PhyreEngine (ports)'],
#   'Platform(s)': ['Microsoft Windows',
#    'OS X',
#    'Linux',
#    'PlayStation 3',
#    'PlayStation 4',
#    'PlayStation Vita',
#    'Android',
#    'Nintendo Switch',
#    'Xbox One',
#    'Stadia'],
#   'Release': ['WW: 23 October 2012',
#    'WW: 18 March 2013',
#    'NA: 25 June 2013',
#    'EU: 26 June 2013',
#    'WW: 9 September 2013',
#    'NA: 19 August 2014',
#    'EU: 20 August 2014',
#    'WW: 30 March 2015',
#    'WW: 19 August 2019',
#    'WW: 7 April 2020',
#    'WW: 22 September 2020'],
#   'Genre(s)': 'Top-down shooter',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'The Walking Dead',
#   'Developer(s)': 'Telltale Games',
#   'Publisher(s)': ['Telltale Games'],
#   'Director(s)': ['Sean Vanaman', 'Jake Rodkin'],
#   'Designer(s)': 'Sean Vanaman Jake Rodkin Mark Darin Harrison G. Pink Andrew Langley Sean Ainsworth',
#   'Programmer(s)': ['Carl Muckenhoupt', 'Randy Tudor', 'Keenan Patterson'],
#   'Artist(s)': ['Derek Sakai'],
#   'Writer(s)': 'Sean Vanaman Mark Darin Gary Whitta',
#   'Composer(s)': 'Jared Emerson-Johnson',
#   'Series': 'The Walking Dead',
#   'Engine': 'Telltale Tool',
#   'Platform(s)': ['Android',
#    'iOS',
#    'Kindle Fire HDX',
#    'OS X',
#    'Linux',
#    'Microsoft Windows',
#    'Nintendo Switch',
#    'Ouya',
#    'PlayStation 3',
#    'PlayStation 4',
#    'PlayStation Vita',
#    'Xbox 360',
#    'Xbox One'],
#   'Release': ['Episode 1',
#    'Episode 2',
#    'Episode 3',
#    'Episode 4',
#    'Episode 5',
#    'Retail version'],
#   'Genre(s)': ['Graphic adventure', 'Interactive drama'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Dota 2',
#   'Developer(s)': 'Valve',
#   'Publisher(s)': ['Valve'],
#   'Designer(s)': 'IceFrog',
#   'Writer(s)': ['Marc Laidlaw', 'Ted Kosmatka', 'Kris Katz'],
#   'Composer(s)': 'Jason Hayes Tim Larkin',
#   'Series': 'Dota',
#   'Engine': 'Source 2',
#   'Platform(s)': ['Microsoft Windows', 'Linux', 'OS X'],
#   'Release': ['Windows', 'July 9, 2013', 'Linux, OS X', 'July 18, 2013'],
#   'Genre(s)': 'MOBA',
#   'Mode(s)': 'Multiplayer'},
#  {'Title': 'Grand Theft Auto V',
#   'Developer(s)': 'Rockstar North',
#   'Publisher(s)': 'Rockstar Games',
#   'Producer(s)': 'Leslie Benzies Imran Sarwar',
#   'Designer(s)': ['Leslie Benzies', 'Imran Sarwar'],
#   'Programmer(s)': ['Adam Fowler'],
#   'Artist(s)': ['Aaron Garbut'],
#   'Writer(s)': 'Dan Houser Rupert Humphries Michael Unsworth',
#   'Composer(s)': ['Tangerine Dream',
#    'Woody Jackson',
#    'The Alchemist',
#    'Oh No'],
#   'Series': 'Grand Theft Auto',
#   'Engine': 'RAGE',
#   'Platform(s)': ['PlayStation 3',
#    'Xbox 360',
#    'PlayStation 4',
#    'Xbox One',
#    'Microsoft Windows',
#    'PlayStation 5',
#    'Xbox Series X/S'],
#   'Release': ['17 September 2013'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'The Last of Us',
#   'Developer(s)': 'Naughty Dog',
#   'Publisher(s)': 'Sony Computer Entertainment',
#   'Director(s)': ['Bruce Straley', 'Neil Druckmann'],
#   'Designer(s)': ['Jacob Minkoff'],
#   'Programmer(s)': ['Travis McIntosh', 'Jason Gregory'],
#   'Artist(s)': ['Erick Pangilinan', 'Nate Wells'],
#   'Writer(s)': ['Neil Druckmann'],
#   'Composer(s)': 'Gustavo Santaolalla',
#   'Platform(s)': ['PlayStation 3', 'PlayStation 4'],
#   'Release': ['WW: June 14, 2013',
#    'NA: July 29, 2014',
#    'PAL: July 30, 2014',
#    'UK: August 1, 2014'],
#   'Genre(s)': ['Action-adventure', 'survival horror'],
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'Destiny',
#   'Developer(s)': 'Bungie',
#   'Publisher(s)': 'Activision (2014–2018) Bungie (2019–present)',
#   'Director(s)': 'Jason Jones',
#   'Producer(s)': ['Jonty Barnes'],
#   'Designer(s)': 'Lars Bakken Del Chafe III Liz M.E. Chung Tyson Green Ken Malcolm Sage Merrill Christopher Opdahl Alex Pfeiffer Luke Smith James Tsai',
#   'Programmer(s)': ['Chris Butcher', 'Ben Wallace', 'Zach Russell'],
#   'Artist(s)': ['Christopher Barrett', 'David Dunn'],
#   'Writer(s)': 'Clay Carmouche Seth Dickinson Jonathan Goff Robt McLees Dave Mongan Joshua Rubin Lily Yu Lucy Precible Felix Gilman',
#   'Composer(s)': ['Michael Salvatori',
#    'C Paul Johnson',
#    "Martin O'Donnell",
#    'Paul McCartney'],
#   'Platform(s)': ['PlayStation 3', 'PlayStation 4', 'Xbox 360', 'Xbox One'],
#   'Release': ['WW: September 9, 2014'],
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer'},
#  {'Title': 'Bloodborne',
#   'Developer(s)': 'FromSoftware',
#   'Publisher(s)': 'Sony Computer Entertainment',
#   'Director(s)': 'Hidetaka Miyazaki',
#   'Producer(s)': ['Masaaki Yamagiwa', 'Teruyuki Toriyama'],
#   'Designer(s)': ['Kazuhiro Hamatani'],
#   'Programmer(s)': ['Jun Ito'],
#   'Artist(s)': ['Ryo Fujimaki'],
#   'Composer(s)': ['Ryan Amon',
#    'Tsukasa Saitoh',
#    'Yuka Kitamura',
#    'Nobuyoshi Suzuki',
#    'Cris Velasco',
#    'Michael Wandmacher'],
#   'Platform(s)': 'PlayStation 4',
#   'Release': ['NA: March 24, 2015',
#    'PAL: March 25, 2015',
#    'JP: March 26, 2015',
#    'UK: March 27, 2015'],
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': ['Single-player', 'multiplayer']},
#  {'Title': 'The Witcher 3: Wild Hunt',
#   'Developer(s)': 'CD Projekt Red',
#   'Publisher(s)': 'CD Projekt',
#   'Director(s)': ['Konrad Tomaszkiewicz',
#    'Mateusz Kanik',
#    'Sebastian Stępień'],
#   'Producer(s)': ['Piotr Krzywonosiuk', 'Jędrzej Mróz'],
#   'Artist(s)': ['Marian Chomiak'],
#   'Writer(s)': ['Marcin Blacha'],
#   'Composer(s)': 'Marcin Przybyłowicz Mikołaj Stroiński',
#   'Series': 'The Witcher',
#   'Engine': 'REDengine 3',
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 4',
#    'PlayStation 5',
#    'Xbox One',
#    'Xbox Series X/S',
#    'Nintendo Switch'],
#   'Release': ['Windows, PS4, Xbox One',
#    '19 May 2015',
#    'Nintendo Switch',
#    '15 October 2019',
#    'PS5, Xbox Series X/S',
#    'Q3/Q4 2021'],
#   'Genre(s)': 'Action role-playing',
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Inside',
#   'Developer(s)': 'Playdead',
#   'Publisher(s)': ['Playdead'],
#   'Director(s)': ['Arnt Jensen'],
#   'Producer(s)': ['Arnt Jensen', 'Dino Patti'],
#   'Composer(s)': 'Martin Stig Andersen Søs Gunver Ryberg',
#   'Engine': 'Unity',
#   'Platform(s)': ['Xbox One',
#    'Microsoft Windows',
#    'PlayStation 4',
#    'Nintendo Switch',
#    'iOS',
#    'macOS'],
#   'Release': ['Xbox One',
#    'June 29, 2016',
#    'Microsoft Windows',
#    'July 7, 2016',
#    'PlayStation 4',
#    'August 23, 2016',
#    'iOS',
#    'December 15, 2017',
#    'Nintendo Switch',
#    'June 28, 2018',
#    'macOS',
#    'June 23, 2020'],
#   'Genre(s)': ['Puzzle-platformer, adventure'],
#   'Mode(s)': 'Single-player'},
#  {'Title': 'Overwatch',
#   'Developer(s)': 'Blizzard Entertainment',
#   'Publisher(s)': ['Blizzard Entertainment'],
#   'Director(s)': ['Jeff Kaplan', 'Chris Metzen', 'Aaron Keller'],
#   'Designer(s)': ['Jeremy Craig', 'Michael Elliott', 'Scott Mercer'],
#   'Programmer(s)': ['Mike Elliott', 'John LeFleur'],
#   'Artist(s)': ['William Petras', 'Arnold Tsang'],
#   'Writer(s)': 'Michael Chu Alyssa Wong',
#   'Composer(s)': ['Derek Duke'],
#   'Platform(s)': ['Microsoft Windows',
#    'PlayStation 4',
#    'Xbox One',
#    'Nintendo Switch'],
#   'Release': ['Windows, PS4, Xbox One',
#    'May 24, 2016',
#    'Nintendo Switch',
#    'October 15, 2019'],
#   'Genre(s)': 'First-person shooter',
#   'Mode(s)': 'Multiplayer'},
#  {'Title': 'The Legend of Zelda: Breath of the Wild',
#   'Developer(s)': 'Nintendo EPD',
#   'Publisher(s)': 'Nintendo',
#   'Director(s)': 'Hidemaro Fujibayashi',
#   'Producer(s)': 'Eiji Aonuma',
#   'Programmer(s)': ['Takuhiro Dohta', 'Kenji Matsutani', 'Hiroshi Umemiya'],
#   'Artist(s)': ['Takumi Wada', 'Satoru Takizawa'],
#   'Writer(s)': ['Akihito Toda'],
#   'Composer(s)': ['Manaka Kataoka', 'Yasuaki Iwata', 'Hajime Wakai'],
#   'Series': 'The Legend of Zelda',
#   'Platform(s)': ['Nintendo Switch', 'Wii U'],
#   'Release': ['March 3', '2017'],
#   'Genre(s)': 'Action-adventure',
#   'Mode(s)': 'Single-player'}]

# %%
#Created a function to save my list as a json file, since it's easier to save dictionaries
#in this file type.
def save(title, data):
    with open(title, "w", encoding="utf8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
        
save("Video Games Data.json", game_info_list)

# %%
#Created a function to load my json file.
def load(title):
    with open(title, "r", encoding="utf8") as f:
        return json.load(f)
    
game_info_list = load("Video Games Data.json")

# %% [markdown]
# # Clean The Data:

# %% [markdown]
# ~~Remove references box from the data and the keys.~~
#
# ~~remove whitespaces from the data.~~
# ### Remove (s) from the dictionary keys, special sign such as "./!" etc and strip whitespaces as well.
# ### Fix release dates.

# %%
[game.get("Release","N/A") for game in game_info_list]
# Out:
# [['NA: December 3, 1971', 'NA: 1975'],
#  ['NA: 29 November 1972', 'JP: November 1973', 'EU: 1973'],
#  ['1977 (PDP-10)',
#   '1980 (',
#   'Zork I',
#   ')',
#   '1981 (',
#   'Zork II',
#   ')',
#   '1982 (',
#   'Zork III',
#   ')'],
#  ['JP: April 1, 1978',
#   'NA: November 1978',
#   'WW: 1978',
#   'NA: March 10, 1980',
#   'EU: 1981'],
#  ['NA: November 1979',
#   'EU: 1979',
#   'JP: January 1980',
#   'NA: July 1981',
#   'NA: 1981',
#   'NA: 1986',
#   'NA: 1992'],
#  ['July 1980'],
#  ['NA: July 1980',
#   'JP: July 1980',
#   'EU: 1980',
#   'NA: April 1981',
#   'NA: 1981',
#   'NA: 1982',
#   'NA: 1987',
#   'NA: 1995',
#   'EU: 1995'],
#  'JP : May 22, 1980 WW : December 1980',
#  ['NA: June 6, 1981', 'EU: 1981', 'JP: March 1983', 'NA: May 3, 1982'],
#  ['NA: Early 1981', 'JP: February 1981', 'EU: 1981'],
#  ['JP: July 9, 1981', 'NA: July 31, 1981', 'EU: November 1981'],
#  ['JP: June 5, 1981', 'NA: September 1981', 'EU: 1981'],
#  ['JP: July 23, 1981', 'EU: 1981', 'NA: October 1981'],
#  'October1981 ( 1981-10 ) : Arcade 1985: Spectrum, BBC 1987: Amstrad 1989: Atari ST',
#  ['NA: July 16, 1982', 'EU: January 1983', 'JP: 1984'],
#  'NA : January 13, 1982',
#  'NA : August 20, 1982',
#  '1982: Arcade 1983: Apple II, Atari 8-bit, 5200, C64, IBM PC, VIC-20 1985: BBC Micro 1986: Atari 7800 1987: Atari ST 1991: Lynx',
#  ['NA: June 23, 1983',
#   'JP: December 1983',
#   'JP: July 1984',
#   'EU: October 1984',
#   'NA: November 1984',
#   'JP: July 31, 1984',
#   'NA: September 1987'],
#  ['NA: May 5, 1983', 'JP: May 1983', 'UK: September 1983', 'SPA: 1983'],
#  ['20 September 1984'],
#  'NA : December 15, 1984',
#  ['USSR: 1984', 'USSR: 1986', 'EU: November 1987', 'NA: January 1988'],
#  ['EU: October 15, 1985', 'NA: November 1985', 'JP: February 1986'],
#  ['JP: July 7, 1985',
#   'NA: September 4, 1985',
#   'EU: October 1985',
#   'JP: June 13, 1986',
#   'NA: November 1, 1986',
#   'EU: 1989',
#   'EU: June 1986',
#   'EU: 1986',
#   'UK: 1990'],
#  ['JP: September 13, 1985',
#   'NA: Late 1985',
#   'EU: May 15, 1987',
#   'AU: 1987',
#   'EU: January 1986',
#   'NA: February 1986'],
#  ['JP: September 1986',
#   'EU: October 1986',
#   'NA: 1986',
#   'JP: October 30, 1987',
#   'NA: November 7, 1988',
#   'EU: October 26, 1990'],
#  ['February 21, 1986'],
#  ['September 1986'],
#  ['February 20, 1987'],
#  ['JP: April 22, 1987',
#   'NA: April 1987',
#   'EU: June 1987',
#   'AU: 1987',
#   'JP: April 8, 1988',
#   'NA: June 24, 1988',
#   'EU: 1990'],
#  ['JP: September 18, 1987', 'NA: October 18, 1987', 'JP: November 21, 1987'],
#  ['May 15, 1987'],
#  ['December 24, 1988'],
#  ['JP: December 9, 1988',
#   'NA: March 13, 1989',
#   'PAL: August 15, 1991',
#   'JP: January 24, 1992'],
#  ['JP: October 23, 1988',
#   'NA: July 15, 1989',
#   'NA: February 12, 1990',
#   'PAL: August 29, 1991'],
#  ['NA: October 3, 1989', 'JP: July 1990', 'EU: September 1990'],
#  ['February 2, 1989'],
#  ['October 1990'],
#  ['1990'],
#  ['21 November 1990'],
#  ['NA: September 22, 2011',
#   'NA/EU: Cancelled',
#   'WW: December 2013',
#   'WW: July 9, 2018'],
#  ['September 1991'],
#  ['JP: November 21, 1991', 'NA: April 13, 1992', 'EU: September 24, 1992'],
#  ['14 February 1991'],
#  'Original version December 1991 Special edition 7 July 2010',
#  ['June 23, 1991'],
#  ['February 6, 1991'],
#  ['NA: 1993', 'EU: 1993'],
#  ['1992',
#   '1993 (MS-DOS',
#   'SNES',
#   'Acorn Archimedes',
#   'Sega Genesis)',
#   'March 1995 (CD-i)'],
#  ['October 8, 1992'],
#  ['November 21, 1992'],
#  ['JP: August 27, 1992',
#   'NA: September 1, 1992',
#   'UK: December 1992',
#   'EU: January 21, 1993'],
#  ['JP: August 1992',
#   'WW: October 1992',
#   'UK: November 1992',
#   'NA: March 14, 1994',
#   'EU: March 16, 1994',
#   'JP: March 18, 1994',
#   'NA: December 12, 1994',
#   'EU: December 14, 1994',
#   'JP: December 16, 1994',
#   'NA: November 6, 1995',
#   'JP: December 22, 1995',
#   'EU: 1996'],
#  ['May\xa05,\xa01992\xa0(1992-05-05)'],
#  'June 25, 1993 MS-DOS , Mac OS NA : June 25, 1993 Win , OS X , PS4 , Vita WW : March 22, 2016 iOS , Linux WW : July 11, 2016 Xbox One WW : October 29, 2020',
#  'JP : March 1994 WW : April 1994',
#  ['December 10, 1993'],
#  ['NA: December 15, 1998'],
#  ['NA: June 25, 1993',
#   'NA: September 9, 1994',
#   'EU: 1994',
#   'NA: October 27, 1994',
#   'EU: October 27, 1994',
#   'NA: December 4, 1994',
#   'EU: 1994',
#   'JP: May 19, 1995',
#   'NA: 1994',
#   'EU: 1994',
#   'EU: 1994',
#   'NA: May 16, 1995',
#   'EU: 1995',
#   'NA: March 28, 1996',
#   'EU: 1996',
#   'JP: March 29, 1996',
#   'JP: August 2, 1996',
#   'NA: April 12, 2007',
#   'EU: June 8, 2007'],
#  ['NA: September 24, 1993',
#   'NA: 1994',
#   'NA: March 17, 1995',
#   'NA: September, 1995',
#   'PAL: September, 1995',
#   'NA: December 14, 1995',
#   'PAL: 1995',
#   'NA: September 30, 1996',
#   'PAL: November 15, 1996'],
#  ['NA: April 1993',
#   'NA: March 4, 1994',
#   'EU: 1994',
#   'JP: April 29, 1994',
#   'NA: November 1994',
#   'EU: November 24, 1994',
#   'JP: 1994',
#   'NA: 1994',
#   'EU: 1994',
#   'JP: December 20, 1994',
#   'NA: February 23, 1995',
#   'EU: February 23, 1995',
#   'JP: February 24, 1995'],
#  ['JP: December 17, 1993', 'NA: February 1995', 'EU: December 8, 1995'],
#  ['November 1993'],
#  ['August 6, 1993'],
#  ['1993'],
#  ['JP: 21 February 1993', 'NA: 26 March 1993', 'EU: 3 June 1993'],
#  ['June 6', '1993'],
#  ['UK: 18 November 1994', 'NA: 21 November 1994', 'EU: 24 November 1994'],
#  ['October 10, 1994'],
#  ['JP: August 27, 1994', 'NA: June 5, 1995'],
#  ['April 2, 1994'],
#  ['October 11, 1994'],
#  ['1994',
#   "1995 (Edition '95/'96)",
#   "1996 (ECE and '96/'97)",
#   '2007 (Xbox 360)'],
#  ['July 1994'],
#  ['JP: March 19, 1994', 'NA: April 18, 1994', 'PAL: July 28, 1994'],
#  ['March 1994'],
#  ['March 11, 1995'],
#  ['September 1995'],
#  'DOS July 24, 1995 Windows December 1995 Mac OS July 1996 PlayStation, Saturn March 1997',
#  ['NA: December 9, 1995',
#   'EU: 1996',
#   'NA: August 31, 1997',
#   'EU: August 31, 1997',
#   'JP: November 27, 1997'],
#  ['29 September 1995'],
#  ['JP: August 5, 1995',
#   'NA: October 4, 1995',
#   'EU: October 6, 1995',
#   'AU: December 1995',
#   'JP: September 20, 2002',
#   'NA: September 23, 2002',
#   'AU: October 4, 2002',
#   'EU: October 11, 2002'],
#  ['NA: February 29, 1996', 'EU: 1996', 'NA: 1997'],
#  ['NA: November 22, 1996',
#   'EU: 1996',
#   'NA: October 25, 1997',
#   'EU: November 1997'],
#  ['January 29, 1996'],
#  ['5 July 1996'],
#  ['JP: 6 December 1996',
#   'EU: 26 September 1997',
#   'NA: 17 November 1997',
#   'JP: 7 December 2006',
#   'EU: 6 July 2007',
#   'NA: 17 July 2007',
#   'AU: 9 August 2007',
#   'WW: 4 April 2017'],
#  ['June 22, 1996'],
#  ['March 22, 1996'],
#  ['JP: June 23, 1996',
#   'NA: September 29, 1996',
#   'EU: March 1, 1997',
#   'CHN: November 21, 2003'],
#  ['25 October 1996'],
#  ['JP: September 27, 1996',
#   'NA: November 1, 1996',
#   'PAL: April 29, 1997',
#   'CHN: November 2003'],
#  ['March 20, 1997'],
#  ['NA: January 3, 1997', 'EU: November 2, 1997', 'NA: March 1998'],
#  ['October 10, 1997'],
#  ['JP: June 20, 1997', 'NA: January 28, 1998'],
#  ['January 31, 1997'],
#  ['25 August 1997'],
#  ['JP: December 23, 1997', 'EU: May 8, 1998', 'NA: May 12, 1998'],
#  ['December 9, 1997'],
#  ['JP: April 27, 1997',
#   'NA: June 30, 1997',
#   'PAL: October 4, 1997',
#   'CHN: November 2003'],
#  'NA : October 10, 1997',
#  ['JP: March 26, 1998', 'NA: April 29, 1998', 'EU: September 12, 1998'],
#  ['September 24', '1997'],
#  ['JP: September 26, 1998',
#   'NA: March 1999',
#   'EU: March 9, 1999',
#   'AS: 1999',
#   'JP: April 10, 1999'],
#  ['October 29', '1998'],
#  'October 30, 1998 Microsoft Windows NA : October 30, 1998 WW : January 27, 2015 ( Remastered ) Linux , OS X , PS4 , Vita WW : January 27, 2015 Android , iOS WW : May 5, 2015 Nintendo Switch WW : November 1, 2018 Xbox One WW : October 29, 2020',
#  ['November 19, 1998'],
#  ['November 21, 1998'],
#  ['September 3, 1998'],
#  ['JP: 29 January 1998', 'NA: 30 April 1998', 'PAL: 5 June 1998'],
#  ['January 21, 1998'],
#  ['NA: March 31, 1998', 'EU: 1998', 'NA: March 12, 1999'],
#  ['NA: December 1, 1998', 'EU: 1998'],
#  ['September 30, 1999'],
#  ['NA: March 16, 1999', 'EU: April 28, 2000', 'NA: June 24, 2003'],
#  'Original release September 28, 1999 (Windows) Remaster February 25, 2015 (Windows) August 6, 2015 (macOS)',
#  ['December 12, 1999',
#   'Enhanced Edition:',
#   'April 11, 2017',
#   '(Windows, macOS, Linux, iOS, Android)',
#   'October 15, 2019',
#   '(Switch, PS4, Xbox One)'],
#  ['December 2, 1999'],
#  ['December 29, 1999'],
#  ['NA: February 23, 1999',
#   'EU: July 16, 1999',
#   'JP: March 4, 1999',
#   'JP: March 21, 2001'],
#  'August 11, 1999 Microsoft Windows NA : August 11, 1999 OS X WW : June 18, 2013 Linux WW : April 1, 2014',
#  ['NA: November 22, 1999',
#   'EU: December 3, 1999',
#   'NA: January 17, 2000',
#   'NA: October 26, 2000',
#   'EU: April 20, 2001',
#   'NA: March 13, 2001',
#   'EU: June 29, 2001'],
#  ['NA: September 21, 2000', 'EU: September 29, 2000', 'NA: September 2001'],
#  ['November 9, 2000'],
#  ['June 23, 2000'],
#  ['NA: June 29, 2000',
#   'EU: June 30, 2000',
#   'WW: July 26, 2000',
#   'WW: March 11, 2016'],
#  ['June 29, 2000'],
#  ['JP: April 27, 2000',
#   'NA: October 26, 2000',
#   'PAL: November 17, 2000',
#   'JP: November 7, 2003',
#   'NA: November 17, 2003',
#   'PAL: March 19, 2004'],
#  ['NA: February 4, 2000',
#   'EU: February 11, 2000',
#   'JP: April 2000',
#   'NA: July 25, 2000',
#   'WW: March 12, 2003',
#   'NA: January 14, 2003',
#   'EU: January 31, 2003',
#   'NA: March 25, 2003',
#   'EU: April 4, 2003'],
#  ['NA: March 23, 2000', 'EU: 2000'],
#  ['September 20, 2000'],
#  ['NA: September 10, 2001',
#   'AU: 2001',
#   'EU: January 11, 2002',
#   'JP: November 25, 2004 (as part of Game Boy Wars Advance 1+2)'],
#  ['JP: April 14, 2001', 'JP: December 14, 2001', 'NA: September 16, 2002'],
#  ['August 23, 2001'],
#  ['JP: July 19, 2001',
#   'NA: December 17, 2001',
#   'AU: May 17, 2002',
#   'EU: May 24, 2002',
#   'JP: January 31, 2002'],
#  ['JP: April 28, 2001', 'NA: July 10, 2001', 'EU: July 20, 2001'],
#  ['22 October 2001'],
#  ['November 15, 2001'],
#  ['NA: September 24, 2001', 'JP: December 6, 2001', 'EU: March 22, 2002'],
#  ['20 December 2001'],
#  ['23 July 2001'],
#  ['November 13, 2001'],
#  ['November 22, 2001'],
#  ['September 24, 2001'],
#  ['JP: November 21, 2001',
#   'NA: December 3, 2001',
#   'EU: May 24, 2002',
#   'AU: May 31, 2002'],
#  ['NA: May 1, 2002',
#   'EU: May 2, 2002',
#   'NA: June 6, 2002',
#   'EU: November 22, 2002'],
#  ['29 October 2002'],
#  ['March 28, 2002'],
#  ['JP: December 13, 2002',
#   'NA: March 24, 2003',
#   'KOR: April 16, 2003',
#   'EU: May 2, 2003',
#   'AU: May 7, 2003'],
#  ['November 17, 2002'],
#  ['July 5, 2002'],
#  ['November 17, 2002'],
#  ['NA: November 11, 2003',
#   'EU: November 14, 2003',
#   'NA: November 19, 2003',
#   'EU: December 5, 2003',
#   'NA: December 2, 2003',
#   'EU: February 27, 2004',
#   'NA: December 11, 2003',
#   'EU: February 27, 2004',
#   'WW: March 2, 2011',
#   'EU: June 8, 2011',
#   'NA: June 28, 2011'],
#  ['14 October 2003'],
#  ['NA: October 28, 2003',
#   'EU: November 14, 2003',
#   'NA: November 10, 2003',
#   'EU: November 21, 2003',
#   'NA: November 18, 2003',
#   'EU: February 20, 2004',
#   'NA: December 2, 2003',
#   'EU: December 5, 2003',
#   'NA: January 8, 2004',
#   'WW: 2022'],
#  ['July 15, 2003'],
#  ['JP: March 21, 2003',
#   'EU: May 23, 2003',
#   'NA: May 26, 2003',
#   'AU: June 6, 2003',
#   'CHN: July 4, 2005'],
#  ['NA: 8 September 2004', 'EU: 10 September 2004'],
#  ['November 27, 2004'],
#  ['26 October 2004'],
#  ['November 16, 2004'],
#  ['November 9, 2004'],
#  ['JP: March 18, 2004', 'NA: September 21, 2004', 'WW: December 7, 2018'],
#  ['November 17, 2004'],
#  ['NA: September 22, 2004', 'EU: October 1, 2004', 'WW: February 5, 2010'],
#  ['AUS/NA: November 23, 2004', 'EU: February 11, 2005'],
#  ['NA: October 25, 2005', 'PAL: November 4, 2005'],
#  ['February 17, 2005'],
#  ['NA: March 22, 2005', 'EU: July 8, 2005'],
#  ['NA: November 8, 2005', 'EU: April 7, 2006', 'AU: June 15, 2006'],
#  ['April 19, 2005'],
#  ['January 11, 2005'],
#  ['NA: October 18, 2005',
#   'JP: October 27, 2005',
#   'AU: February 16, 2006',
#   'EU: February 17, 2006'],
#  ['March 21, 2005'],
#  ['NA: September 12, 2006',
#   'EU: September 29, 2006',
#   'iPadOS: February 13, 2020'],
#  ['March 20, 2006'],
#  ['NA: November 7, 2006',
#   'EU: November 17, 2006',
#   'AU: November 23, 2006',
#   'NA: November 6, 2007',
#   'EU: November 9, 2007',
#   'AU: November 15, 2007'],
#  ['EU: 26 May 2006', 'NA: 30 May 2006'],
#  ['20 April 2006'],
#  ['NA: November 19, 2006',
#   'JP: December 2, 2006',
#   'AU: December 7, 2006',
#   'EU: December 8, 2006',
#   'KOR: April 26, 2008'],
#  ['August 21, 2007'],
#  ['November 5, 2007'],
#  ['NA: March 13, 2007', 'EU: April 27, 2007', 'AU: May 3, 2007'],
#  ['NA: September 25, 2007',
#   'AU: September 25, 2007',
#   'EU: September 26, 2007',
#   'WW: November 11, 2014',
#   'WW: July 14, 2020',
#   'WW: November 17, 2020'],
#  ['November 20, 2007'],
#  ['October 10, 2007'],
#  ['NA: November 20, 2007',
#   'EU: May 23, 2008',
#   'AU: November 7, 2008',
#   'NA: November 20, 2007',
#   'EU: September 12, 2008',
#   'AU: November 7, 2008',
#   'NA: December 17, 2007',
#   'EU: September 12, 2008',
#   'AU: November 7, 2008',
#   'NA: June 22, 2008',
#   'EU: September 12, 2008',
#   'AU: November 7, 2008'],
#  ['JP: 1 November 2007',
#   'NA: 12 November 2007',
#   'EU: 16 November 2007',
#   'AU: 29 November 2007',
#   'CHN: 22 March 2018'],
#  ['October 10, 2007'],
#  ['NA: August 6, 2008',
#   'WW: April 10, 2009',
#   'WW: May 20, 2009',
#   'NA: November 12, 2009',
#   'PAL: December 17, 2009',
#   'WW: December 14, 2010',
#   'WW: 2021'],
#  ['NA: 22 January 2008',
#   'EU: 25 January 2008',
#   'AU: 7 February 2008',
#   'NA: 5 February 2009 (PC)',
#   'NA: 6 February 2009',
#   'EU: 6 February 2009',
#   'AU: 12 March 2009',
#   'WW: 16 March 2018 (PS4, XBO)',
#   'WW: 21 August 2018 (PC)',
#   'WW: 19 June 2020 (Switch)'],
#  ['NA: October 13, 2008',
#   'NA: October 20, 2008 (PC)',
#   'AU: October 23, 2008',
#   'EU: October 24, 2008'],
#  ['NA: October 28, 2008', 'PAL: October 30, 2008'],
#  ['WW: November 7', '2008', 'JP: July 30', '2009'],
#  ['WW: 29 April 2008', 'NA: 2 December 2008', 'PAL: 3 December 2008'],
#  ['November 17, 2008'],
#  ['27 October 2008'],
#  ['July 10, 2008'],
#  ['NA: September 14, 2008',
#   'EU: October 19, 2008 (Bundle)',
#   'EU: November 21, 2008',
#   'NA: October 19, 2008',
#   'EU: March 27, 2009',
#   'NA: December 18, 2008',
#   'EU: March 27, 2009',
#   'NA: December 18, 2008',
#   'EU: October 9, 2009'],
#  ['WW: December 21, 2008',
#   'WW: August 8, 2013 (remake)',
#   'NA: July 4, 2012',
#   'EU: July 5, 2012',
#   'NA: August 27, 2013',
#   'EU: August 28, 2013',
#   'NA: October 7, 2014',
#   'EU: October 8, 2014'],
#  ['JP: July 18, 2008',
#   'NA: August 2008',
#   'JP: February 12, 2009',
#   'NA: February 17, 2009',
#   'EU: February 20, 2009',
#   'JP: July 2, 2009',
#   'EU: July 3, 2009',
#   'NA: July 7, 2009'],
#  ['JP: April 24, 2008', 'UK: October 31, 2008', 'NA: November 4, 2008'],
#  ['December 11, 2009'],
#  ['NA: November 17, 2009',
#   'AU: November 19, 2009',
#   'EU: November 20, 2009',
#   'AU: March 4, 2010',
#   'EU: March 5, 2010',
#   'NA: March 9, 2010',
#   'EU: October 1, 2010',
#   'NA: January 6, 2011',
#   'WW: November 15, 2016'],
#  ['August 25, 2009'],
#  ['October 29, 2009'],
#  ['November 3, 2009'],
#  ['November 17, 2009'],
#  ['NA: October 13, 2009', 'AU: October 15, 2009', 'EU: October 16, 2009'],
#  ['21 July 2010'],
#  ['January 26, 2010'],
#  ['NA: May 18, 2010', 'PAL: May 21, 2010'],
#  ['NA: October 26, 2010', 'AU: October 28, 2010', 'EU: October 29, 2010'],
#  ['July 27', '2010'],
#  ['NA: May 23, 2010',
#   'JP: May 27, 2010',
#   'EU: June 11, 2010',
#   'AU: July 1, 2010'],
#  ['October 20, 2010'],
#  ['October 18, 2011'],
#  ['September 22, 2011'],
#  ['PC, PS3, Xbox 360',
#   'November 11, 2011',
#   'PS4, Xbox One',
#   'October 28, 2016',
#   'Nintendo Switch',
#   'November 17, 2017'],
#  ['18 November 2011'],
#  ['April 18, 2011'],
#  ['9 October 2012'],
#  ['NA: March 13, 2012', 'EU: March 14, 2012', 'NA: July 21, 2015'],
#  ['WW: 23 October 2012',
#   'WW: 18 March 2013',
#   'NA: 25 June 2013',
#   'EU: 26 June 2013',
#   'WW: 9 September 2013',
#   'NA: 19 August 2014',
#   'EU: 20 August 2014',
#   'WW: 30 March 2015',
#   'WW: 19 August 2019',
#   'WW: 7 April 2020',
#   'WW: 22 September 2020'],
#  ['Episode 1',
#   'Episode 2',
#   'Episode 3',
#   'Episode 4',
#   'Episode 5',
#   'Retail version'],
#  ['Windows', 'July 9, 2013', 'Linux, OS X', 'July 18, 2013'],
#  ['17 September 2013'],
#  ['WW: June 14, 2013',
#   'NA: July 29, 2014',
#   'PAL: July 30, 2014',
#   'UK: August 1, 2014'],
#  ['WW: September 9, 2014'],
#  ['NA: March 24, 2015',
#   'PAL: March 25, 2015',
#   'JP: March 26, 2015',
#   'UK: March 27, 2015'],
#  ['Windows, PS4, Xbox One',
#   '19 May 2015',
#   'Nintendo Switch',
#   '15 October 2019',
#   'PS5, Xbox Series X/S',
#   'Q3/Q4 2021'],
#  ['Xbox One',
#   'June 29, 2016',
#   'Microsoft Windows',
#   'July 7, 2016',
#   'PlayStation 4',
#   'August 23, 2016',
#   'iOS',
#   'December 15, 2017',
#   'Nintendo Switch',
#   'June 28, 2018',
#   'macOS',
#   'June 23, 2020'],
#  ['Windows, PS4, Xbox One',
#   'May 24, 2016',
#   'Nintendo Switch',
#   'October 15, 2019'],
#  ['March 3', '2017']]

# %%
'October1981 ( 1981-10 )
"(1992-05-05)"

# %% [markdown]
# ## Date Cleaning & modifying:

# %%
lst = ['June 23, 2020']
(lst[0])
# Out:
# 'June 23, 2020'

# %% [markdown]
# # Date types that needs to be handled:
# ~~1. 'March 3', '2017'.~~
#
# ~~2. '15 October 2019'.~~
#
# 3. The Walking Dead - take from the list the first date - "https://en.wikipedia.org/wiki/The_Walking_Dead_(video_game)"
#
# ~~4. 'WW: August 8, 2013 (remake)' - take the date with no other stuff.~~
#
# ~~5. take the first date that is in a list - ['NA: October 28, 2008', 'PAL: October 30, 2008']~~
#
# ~~6. remove the release at the countries - JP, NA, etc.~~
#
# ~~7. take the first date if there is a string before it -  ['Windows', 'July 9, 2013', 'Linux, OS X', 'July 18, 2013']~~
#
# 8. check for games that only have a year or a month & a year, and if there are only a few - enter them manually. otherwise, skip them.
#
# ~~9. handle single date in a list -['March 3', '2017']~~
#
# ~~10.  ['NA: November 1979']~~
#
# 11. 'October1981 ( 1981-10 )
#
# 12. "(1992-05-05)"

# %%
m_d_y = r"\w+\s\d+(,)\s\d{4}" #Month Day, Year. 
d_m_y = r"\d+\s\w+\s\d{4}" #Day, Month, Year.
m_y = r"\w+\s\d{4}" #Month and Year.
m_y_2 =r"^\w+\d{4}" #Another month and Year format.
y = r"\d{4}" #Year only.
datetime_fmt = r"(\d{4}(-)\d{2}-\d{2})$" #Dates that had a datetime format in the page it self.

def datetime_fmt_version(date):
    value = datetime.strptime(date,'%Y-%m-%d')
    value = value.strftime('%Y-%m-%d')
    return value

def m_d_y_version(date):
    value = datetime.strptime(date,'%B %d, %Y')
    value = value.strftime('%Y-%m-%d')
    return value

def d_m_y_version(date):
    value = datetime.strptime(date,'%d %B %Y')
    value = value.strftime('%Y-%m-%d')
    return value

def m_y_version(date):
    value = datetime.strptime(date,'%B %Y')
    value = value.strftime('%Y-%m')
    return value

def m_y_2_version(date):
    value = datetime.strptime(date,'%B%Y')
    value = value.strftime('%Y-%m')
    return value

def y_version(date):
    value = datetime.strptime(date,'%Y')
    value = value.strftime('%Y')
    return value

def dates_in_list(date):
    try:
        if re.search(m_d_y,date[0]):
            value = re.search(m_d_y,date[0]).group()
            return m_d_y_version(value)
    except:
        pass
    try:
        if re.search(d_m_y,date[0]):
            value = re.search(d_m_y,date[0]).group()
            return d_m_y_version(value) 
    except:
        pass
    try:
        if re.search(m_d_y,date[0])==None:
            value = re.search(m_d_y,date[1]).group()
            return m_d_y_version(value)
    except:
        pass
    try:
        if re.search(d_m_y,date[0])==None:
            value = re.search(d_m_y,date[1]).group()
            return d_m_y_version(value)
    except:
        pass
    try:
        if re.search(m_y,date[0]):
            value = re.search(m_y,date[0]).group()
            return m_y_version(value)
    except:
        pass
    try:
        if re.search(m_y,date[0]):
            value = re.search(m_y,date[1]).group()
            return m_y_version(value)
    except:
        pass
    try:
        if re.search(m_y_2,date[0]):
            value = re.search(m_y_2,date[0]).group()
            return m_y_2_version(value)
    except:
        pass
    try:
        if re.search(m_y_2,date[0]):
            value = re.search(m_y_2,date[1]).group()
            return m_y_2_version(value)
    except:
        pass
    try:
        if re.search(datetime_fmt,date[0]):
            value = re.search(datetime_fmt,date[0]).group()
            return datetime_fmt_version(value)
    except:
        pass
    try:
        if re.search(datetime_fmt,date[0]):
            value = re.search(datetime_fmt,date[1]).group()
            return datetime_fmt_version(value)
    except:
        pass
    try:
        if re.search(y,date[0]):
            value = re.search(y,date[0]).group()
            return y_version(value)
    except:
        pass
    try:
        if re.search(y,date[0]):
            value = re.search(y,date[1]).group()
            return y_version(value)
    except:
        pass
    
def combine_lst_dates(date):
    value = ", ".join(date)
    return m_d_y_version(value)

# %%
def date_conversion(date):
    if isinstance(date,list):
        return dates_in_list(date)
    elif re.search(m_d_y,date):
        value = re.search(m_d_y,date).group()
        return m_d_y_version(value)
    elif re.search(d_m_y,date):
        value = re.search(d_m_y,date).group()
        return d_m_y_version(value)
    elif re.match(m_y,date):
        value = re.search(m_y,date).group()
        return m_y_version(value)
    elif re.search(m_y_2,date):
        value = re.search(m_y_2,date).group()
        return m_y_2_version(value)
    elif re.search(datetime_fmt,date):
        value = re.search(datetime_fmt,date).group()
        return datetime_fmt_version(value)
    elif re.search(y,date):
        value = re.search(y,date).group()
        return y_version(value)
    
     

# date_conversion(['June 6', '1993']) # --> try to concatenate them and print as usual.
# date_conversion(['October1981 ( 1981-10 )'])
# date_conversion(["(1992-05-05)"]) # --> not working yet - returning only the year!
# date_conversion("(1992-05-05)") # --> not working yet - returning only the year!
# date_conversion('October1981 ( 1981-10 ) : Arcade 1985: Spectrum, BBC 1987: Amstrad 1989: Atari ST')    
# date_conversion(["1987",'EU: June 1986'])    
# date_conversion('July 9, 2013')
# date_conversion('9 July 2013')
# date_conversion(['NA: December 3, 1971', 'NA: 1975'])
# date_conversion(['9 July 2013'])
# date_conversion(['Windows','9 July 2013', 'Linux, OS X', 'July 18, 2013'])
# date_conversion(['Windows','July 9, 2013', 'Linux, OS X', 'July 18, 2013'])
# date_conversion(['July 9, 2013','Windows', 'Linux, OS X', 'July 18, 2013'])
# date_conversion(['9 July 2013','Windows', 'Linux, OS X', 'July 18, 2013'])

# %%
combine_lst_dates(['June 6', '1993'])
# Out:
# '1993-06-06'

# %%
lst = ['June 6', '1993']
lst = ", ".join(lst)
date_conversion(lst)
# Out:
# '1993-06-06'

# %%
game_info_list[235]
# Out:
# {'Title': 'The Legend of Zelda: Breath of the Wild',
#  'Developer(s)': 'Nintendo EPD',
#  'Publisher(s)': 'Nintendo',
#  'Director(s)': 'Hidemaro Fujibayashi',
#  'Producer(s)': 'Eiji Aonuma',
#  'Programmer(s)': ['Takuhiro Dohta', 'Kenji Matsutani', 'Hiroshi Umemiya'],
#  'Artist(s)': ['Takumi Wada', 'Satoru Takizawa'],
#  'Writer(s)': ['Akihito Toda'],
#  'Composer(s)': ['Manaka Kataoka', 'Yasuaki Iwata', 'Hajime Wakai'],
#  'Series': 'The Legend of Zelda',
#  'Platform(s)': ['Nintendo Switch', 'Wii U'],
#  'Release': ['March 3', '2017'],
#  'Genre(s)': 'Action-adventure',
#  'Mode(s)': 'Single-player'}

# %%
for index, game in enumerate(game_info_list):
    print(index)
    print(date_conversion(game.get("Release","N/A")))
# Out:
# 0
# 1971-12-03
# 1
# 1972-11-29
# 2
# 1977
# 3
# 1978-04-01
# 4
# 1979-11
# 5
# 1980-07
# 6
# 1980-07
# 7
# 1980-05-22
# 8
# 1981-06-06
# 9
# 1981-02
# 10
# 1981-07-09
# 11
# 1981-06-05
# 12
# 1981-07-23
# 13
# 1981-10
# 14
# 1982-07-16
# 15
# 1982-01-13
# 16
# 1982-08-20
# 17
# 1982
# 18
# 1983-06-23
# 19
# 1983-05-05
# 20
# 1984-09-20
# 21
# 1984-12-15
# 22
# 1984
# 23
# 1985-10-15
# 24
# 1985-07-07
# 25
# 1985-09-13
# 26
# 1986-09
# 27
# 1986-02-21
# 28
# 1986-09
# 29
# 1987-02-20
# 30
# 1987-04-22
# 31
# 1987-09-18
# 32
# 1987-05-15
# 33
# 1988-12-24
# 34
# 1988-12-09
# 35
# 1988-10-23
# 36
# 1989-10-03
# 37
# 1989-02-02
# 38
# 1990-10
# 39
# 1990
# 40
# 1990-11-21
# 41
# 2011-09-22
# 42
# 1991-09
# 43
# 1991-11-21
# 44
# 1991-02-14
# 45
# 2010-07-07
# 46
# 1991-06-23
# 47
# 1991-02-06
# 48
# 1993
# 49
# 1992
# 50
# 1992-10-08
# 51
# 1992-11-21
# 52
# 1992-08-27
# 53
# 1992-08
# 54
# 1992-05-05
# 55
# 1993-06-25
# 56
# 1994
# 57
# 1993-12-10
# 58
# 1998-12-15
# 59
# 1993-06-25
# 60
# 1993-09-24
# 61
# 1994-03-04
# 62
# 1993-12-17
# 63
# 1993-11
# 64
# 1993-08-06
# 65
# 1993
# 66
# 1993-02-21
# 67
# None
# 68
# 1994-11-18
# 69
# 1994-10-10
# 70
# 1994-08-27
# 71
# 1994-04-02
# 72
# 1994-10-11
# 73
# 1994
# 74
# 1994-07
# 75
# 1994-03-19
# 76
# 1994-03
# 77
# 1995-03-11
# 78
# 1995-09
# 79
# 1995-07-24
# 80
# 1995-12-09
# 81
# 1995-09-29
# 82
# 1995-08-05
# 83
# 1996-02-29
# 84
# 1996-11-22
# 85
# 1996-01-29
# 86
# 1996-07-05
# 87
# 1996-12-06
# 88
# 1996-06-22
# 89
# 1996-03-22
# 90
# 1996-06-23
# 91
# 1996-10-25
# 92
# 1996-09-27
# 93
# 1997-03-20
# 94
# 1997-01-03
# 95
# 1997-10-10
# 96
# 1997-06-20
# 97
# 1997-01-31
# 98
# 1997-08-25
# 99
# 1997-12-23
# 100
# 1997-12-09
# 101
# 1997-04-27
# 102
# 1997-10-10
# 103
# 1998-03-26
# 104
# None
# 105
# 1998-09-26
# 106
# None
# 107
# 1998-10-30
# 108
# 1998-11-19
# 109
# 1998-11-21
# 110
# 1998-09-03
# 111
# 1998-01-29
# 112
# 1998-01-21
# 113
# 1998-03-31
# 114
# 1998-12-01
# 115
# 1999-09-30
# 116
# 1999-03-16
# 117
# 1999-09-28
# 118
# 1999-12-12
# 119
# 1999-12-02
# 120
# 1999-12-29
# 121
# 1999-02-23
# 122
# 1999-08-11
# 123
# 1999-11-22
# 124
# 2000-09-21
# 125
# 2000-11-09
# 126
# 2000-06-23
# 127
# 2000-06-29
# 128
# 2000-06-29
# 129
# 2000-04-27
# 130
# 2000-02-04
# 131
# 2000-03-23
# 132
# 2000-09-20
# 133
# 2001-09-10
# 134
# 2001-04-14
# 135
# 2001-08-23
# 136
# 2001-07-19
# 137
# 2001-04-28
# 138
# 2001-10-22
# 139
# 2001-11-15
# 140
# 2001-09-24
# 141
# 2001-12-20
# 142
# 2001-07-23
# 143
# 2001-11-13
# 144
# 2001-11-22
# 145
# 2001-09-24
# 146
# 2001-11-21
# 147
# 2002-05-01
# 148
# 2002-10-29
# 149
# 2002-03-28
# 150
# 2002-12-13
# 151
# 2002-11-17
# 152
# 2002-07-05
# 153
# 2002-11-17
# 154
# 2003-11-11
# 155
# 2003-10-14
# 156
# 2003-10-28
# 157
# 2003-07-15
# 158
# 2003-03-21
# 159
# 2004-09-08
# 160
# 2004-11-27
# 161
# 2004-10-26
# 162
# 2004-11-16
# 163
# 2004-11-09
# 164
# 2004-03-18
# 165
# 2004-11-17
# 166
# 2004-09-22
# 167
# 2004-11-23
# 168
# 2005-10-25
# 169
# 2005-02-17
# 170
# 2005-03-22
# 171
# 2005-11-08
# 172
# 2005-04-19
# 173
# 2005-01-11
# 174
# 2005-10-18
# 175
# 2005-03-21
# 176
# 2006-09-12
# 177
# 2006-03-20
# 178
# 2006-11-07
# 179
# 2006-05-26
# 180
# 2006-04-20
# 181
# 2006-11-19
# 182
# 2007-08-21
# 183
# 2007-11-05
# 184
# 2007-03-13
# 185
# 2007-09-25
# 186
# 2007-11-20
# 187
# 2007-10-10
# 188
# 2007-11-20
# 189
# 2007-11-01
# 190
# 2007-10-10
# 191
# 2008-08-06
# 192
# 2008-01-22
# 193
# 2008-10-13
# 194
# 2008-10-28
# 195
# None
# 196
# 2008-04-29
# 197
# 2008-11-17
# 198
# 2008-10-27
# 199
# 2008-07-10
# 200
# 2008-09-14
# 201
# 2008-12-21
# 202
# 2008-07-18
# 203
# 2008-04-24
# 204
# 2009-12-11
# 205
# 2009-11-17
# 206
# 2009-08-25
# 207
# 2009-10-29
# 208
# 2009-11-03
# 209
# 2009-11-17
# 210
# 2009-10-13
# 211
# 2010-07-21
# 212
# 2010-01-26
# 213
# 2010-05-18
# 214
# 2010-10-26
# 215
# None
# 216
# 2010-05-23
# 217
# 2010-10-20
# 218
# 2011-10-18
# 219
# 2011-09-22
# 220
# 2011-11-11
# 221
# 2011-11-18
# 222
# 2011-04-18
# 223
# 2012-10-09
# 224
# 2012-03-13
# 225
# 2012-10-23
# 226
# None
# 227
# 2013-07-09
# 228
# 2013-09-17
# 229
# 2013-06-14
# 230
# 2014-09-09
# 231
# 2015-03-24
# 232
# 2015-05-19
# 233
# 2016-06-29
# 234
# 2016-05-24
# 235
# None
